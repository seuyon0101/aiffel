# %% [markdown]
# # Exploration 02 : Regression
#
# ---
#
#
# # 🩺👨‍⚕️ 프로젝트 1 : 손수 설계하는 선형회귀, 당뇨병 수치를 맞춰보자!

# %% [markdown]
# ## (1) 데이터 가져오기

# %% [markdown]
# - sklearn.datasets의 load_diabetes에서 데이터를 가져와주세요.
# - diabetes의 data를 df_X에, target을 df_y에 저장해주세요.

# %%
from sklearn.datasets import load_diabetes
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
diabetes_data = load_diabetes()
df_X = diabetes_data.data
df_y = diabetes_data.target

# %%
print(type(df_X))
print(type(df_y))
print(df_X.shape)
print(df_y.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (442, 10)
# (442,)

# %%
print(diabetes_data.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
#       - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %%
ddf = pd.DataFrame(data  = df_X, columns = diabetes_data.feature_names)

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
ddf.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -1.444295e-18  2.543215e-18 -2.255925e-16 -4.854086e-17 -1.428596e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.898811e-17 -6.028360e-18 -1.788100e-17  9.243486e-17  1.351770e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260971e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324559e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947171e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243232e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335973e-01  1.356118e-01

# %%
ddf['target'] = diabetes_data.target

# %%
ddf.corr().style.background_gradient(cmap = 'YlGn')
# Out:
# <style type="text/css">
# #T_f8e35_row0_col0, #T_f8e35_row1_col1, #T_f8e35_row2_col2, #T_f8e35_row3_col3, #T_f8e35_row4_col4, #T_f8e35_row5_col5, #T_f8e35_row6_col6, #T_f8e35_row7_col7, #T_f8e35_row8_col8, #T_f8e35_row9_col9, #T_f8e35_row10_col10 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_f8e35_row0_col1 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_f8e35_row0_col2 {
#   background-color: #a1d889;
#   color: #000000;
# }
# #T_f8e35_row0_col3, #T_f8e35_row4_col10 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_f8e35_row0_col4, #T_f8e35_row1_col0 {
#   background-color: #ddf2a6;
#   color: #000000;
# }
# #T_f8e35_row0_col5 {
#   background-color: #b8e293;
#   color: #000000;
# }
# #T_f8e35_row0_col6, #T_f8e35_row2_col5, #T_f8e35_row3_col0 {
#   background-color: #abdc8d;
#   color: #000000;
# }
# #T_f8e35_row0_col7, #T_f8e35_row7_col9 {
#   background-color: #66bd70;
#   color: #f1f1f1;
# }
# #T_f8e35_row0_col8 {
#   background-color: #81ca7d;
#   color: #000000;
# }
# #T_f8e35_row0_col9, #T_f8e35_row3_col1, #T_f8e35_row4_col2 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_f8e35_row0_col10 {
#   background-color: #9cd687;
#   color: #000000;
# }
# #T_f8e35_row1_col2 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_f8e35_row1_col3, #T_f8e35_row4_col3 {
#   background-color: #b3e091;
#   color: #000000;
# }
# #T_f8e35_row1_col4, #T_f8e35_row6_col0, #T_f8e35_row6_col1, #T_f8e35_row6_col2, #T_f8e35_row6_col3, #T_f8e35_row6_col5, #T_f8e35_row6_col7, #T_f8e35_row6_col8, #T_f8e35_row6_col9, #T_f8e35_row6_col10, #T_f8e35_row7_col6 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_f8e35_row1_col5 {
#   background-color: #ceeb9e;
#   color: #000000;
# }
# #T_f8e35_row1_col6 {
#   background-color: #e4f4ab;
#   color: #000000;
# }
# #T_f8e35_row1_col7 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_f8e35_row1_col8 {
#   background-color: #a6da8b;
#   color: #000000;
# }
# #T_f8e35_row1_col9, #T_f8e35_row5_col1 {
#   background-color: #acdd8e;
#   color: #000000;
# }
# #T_f8e35_row1_col10 {
#   background-color: #c3e698;
#   color: #000000;
# }
# #T_f8e35_row2_col0 {
#   background-color: #dcf1a5;
#   color: #000000;
# }
# #T_f8e35_row2_col1 {
#   background-color: #bae394;
#   color: #000000;
# }
# #T_f8e35_row2_col3, #T_f8e35_row8_col3 {
#   background-color: #7ec97b;
#   color: #000000;
# }
# #T_f8e35_row2_col4 {
#   background-color: #e0f3a8;
#   color: #000000;
# }
# #T_f8e35_row2_col6, #T_f8e35_row3_col4 {
#   background-color: #e2f4aa;
#   color: #000000;
# }
# #T_f8e35_row2_col7 {
#   background-color: #389f55;
#   color: #f1f1f1;
# }
# #T_f8e35_row2_col8 {
#   background-color: #4ab062;
#   color: #f1f1f1;
# }
# #T_f8e35_row2_col9, #T_f8e35_row3_col9 {
#   background-color: #6fc174;
#   color: #000000;
# }
# #T_f8e35_row2_col10 {
#   background-color: #2e924c;
#   color: #f1f1f1;
# }
# #T_f8e35_row3_col2, #T_f8e35_row9_col10 {
#   background-color: #5fba6c;
#   color: #f1f1f1;
# }
# #T_f8e35_row3_col5 {
#   background-color: #c1e698;
#   color: #000000;
# }
# #T_f8e35_row3_col6, #T_f8e35_row8_col0 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_f8e35_row3_col7, #T_f8e35_row7_col2 {
#   background-color: #58b669;
#   color: #f1f1f1;
# }
# #T_f8e35_row3_col8 {
#   background-color: #5cb86b;
#   color: #f1f1f1;
# }
# #T_f8e35_row3_col10 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_f8e35_row4_col0, #T_f8e35_row5_col3, #T_f8e35_row5_col6, #T_f8e35_row10_col5 {
#   background-color: #c4e799;
#   color: #000000;
# }
# #T_f8e35_row4_col1 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_f8e35_row4_col5 {
#   background-color: #005d33;
#   color: #f1f1f1;
# }
# #T_f8e35_row4_col6 {
#   background-color: #8bce81;
#   color: #000000;
# }
# #T_f8e35_row4_col7 {
#   background-color: #268846;
#   color: #f1f1f1;
# }
# #T_f8e35_row4_col8 {
#   background-color: #3aa257;
#   color: #f1f1f1;
# }
# #T_f8e35_row4_col9 {
#   background-color: #84cb7e;
#   color: #000000;
# }
# #T_f8e35_row5_col0 {
#   background-color: #d0ec9f;
#   color: #000000;
# }
# #T_f8e35_row5_col2 {
#   background-color: #89ce80;
#   color: #000000;
# }
# #T_f8e35_row5_col4 {
#   background-color: #006335;
#   color: #f1f1f1;
# }
# #T_f8e35_row5_col7 {
#   background-color: #14783e;
#   color: #f1f1f1;
# }
# #T_f8e35_row5_col8, #T_f8e35_row10_col9 {
#   background-color: #72c376;
#   color: #000000;
# }
# #T_f8e35_row5_col9 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_f8e35_row5_col10, #T_f8e35_row9_col5 {
#   background-color: #9fd788;
#   color: #000000;
# }
# #T_f8e35_row6_col4 {
#   background-color: #feffdf;
#   color: #000000;
# }
# #T_f8e35_row7_col0 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# #T_f8e35_row7_col1 {
#   background-color: #70c275;
#   color: #000000;
# }
# #T_f8e35_row7_col3 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_f8e35_row7_col4, #T_f8e35_row10_col3 {
#   background-color: #6dc073;
#   color: #000000;
# }
# #T_f8e35_row7_col5 {
#   background-color: #2b8e4a;
#   color: #f1f1f1;
# }
# #T_f8e35_row7_col8 {
#   background-color: #288a47;
#   color: #f1f1f1;
# }
# #T_f8e35_row7_col10 {
#   background-color: #4fb264;
#   color: #f1f1f1;
# }
# #T_f8e35_row8_col1 {
#   background-color: #a9db8c;
#   color: #000000;
# }
# #T_f8e35_row8_col2 {
#   background-color: #4eb163;
#   color: #f1f1f1;
# }
# #T_f8e35_row8_col4 {
#   background-color: #79c679;
#   color: #000000;
# }
# #T_f8e35_row8_col5 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_f8e35_row8_col6, #T_f8e35_row10_col6 {
#   background-color: #e6f5ac;
#   color: #000000;
# }
# #T_f8e35_row8_col7 {
#   background-color: #1a7d40;
#   color: #f1f1f1;
# }
# #T_f8e35_row8_col9 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_f8e35_row8_col10, #T_f8e35_row10_col8 {
#   background-color: #31974f;
#   color: #f1f1f1;
# }
# #T_f8e35_row9_col0 {
#   background-color: #b6e192;
#   color: #000000;
# }
# #T_f8e35_row9_col1 {
#   background-color: #97d385;
#   color: #000000;
# }
# #T_f8e35_row9_col2 {
#   background-color: #61bb6d;
#   color: #f1f1f1;
# }
# #T_f8e35_row9_col3 {
#   background-color: #7fc97c;
#   color: #000000;
# }
# #T_f8e35_row9_col4 {
#   background-color: #c7e89a;
#   color: #000000;
# }
# #T_f8e35_row9_col6 {
#   background-color: #d3eda0;
#   color: #000000;
# }
# #T_f8e35_row9_col7 {
#   background-color: #379e54;
#   color: #f1f1f1;
# }
# #T_f8e35_row9_col8 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_f8e35_row10_col0 {
#   background-color: #dbf1a4;
#   color: #000000;
# }
# #T_f8e35_row10_col1 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_f8e35_row10_col2 {
#   background-color: #2f944e;
#   color: #f1f1f1;
# }
# #T_f8e35_row10_col4 {
#   background-color: #eaf7af;
#   color: #000000;
# }
# #T_f8e35_row10_col7 {
#   background-color: #359c53;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f8e35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8e35_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_f8e35_level0_col1" class="col_heading level0 col1" >sex</th>
#       <th id="T_f8e35_level0_col2" class="col_heading level0 col2" >bmi</th>
#       <th id="T_f8e35_level0_col3" class="col_heading level0 col3" >bp</th>
#       <th id="T_f8e35_level0_col4" class="col_heading level0 col4" >s1</th>
#       <th id="T_f8e35_level0_col5" class="col_heading level0 col5" >s2</th>
#       <th id="T_f8e35_level0_col6" class="col_heading level0 col6" >s3</th>
#       <th id="T_f8e35_level0_col7" class="col_heading level0 col7" >s4</th>
#       <th id="T_f8e35_level0_col8" class="col_heading level0 col8" >s5</th>
#       <th id="T_f8e35_level0_col9" class="col_heading level0 col9" >s6</th>
#       <th id="T_f8e35_level0_col10" class="col_heading level0 col10" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8e35_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_f8e35_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f8e35_row0_col1" class="data row0 col1" >0.173737</td>
#       <td id="T_f8e35_row0_col2" class="data row0 col2" >0.185085</td>
#       <td id="T_f8e35_row0_col3" class="data row0 col3" >0.335428</td>
#       <td id="T_f8e35_row0_col4" class="data row0 col4" >0.260061</td>
#       <td id="T_f8e35_row0_col5" class="data row0 col5" >0.219243</td>
#       <td id="T_f8e35_row0_col6" class="data row0 col6" >-0.075181</td>
#       <td id="T_f8e35_row0_col7" class="data row0 col7" >0.203841</td>
#       <td

# %%
fig = plt.figure(figsize = (10,10))
for i, col in enumerate(ddf.columns) :
    ax = fig.add_subplot(6,2,i+1)
    sns.kdeplot(data=ddf,x=col)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## (2) 모델에 입력할 데이터 X 준비하기

# %% [markdown]
# - df_X에 있는 값들을 numpy array로 변환해서 저장해주세요.

# %%
df_X = np.array(df_X)
print(df_X)
# Out:
# [[ 0.03807591  0.05068012  0.06169621 ... -0.00259226  0.01990749
#   -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 ... -0.03949338 -0.06833155
#   -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 ... -0.00259226  0.00286131
#   -0.02593034]
#  ...
#  [ 0.04170844  0.05068012 -0.01590626 ... -0.01107952 -0.04688253
#    0.01549073]
#  [-0.04547248 -0.04464164  0.03906215 ...  0.02655962  0.04452873
#   -0.02593034]
#  [-0.04547248 -0.04464164 -0.0730303  ... -0.03949338 -0.00422151
#    0.00306441]]

# %% [markdown]
# ## (3) 모델에 예측할 데이터 y 준비하기

# %% [markdown]
# - df_y에 있는 값들을 numpy array로 변환해서 저장해주세요.

# %%
df_X = np.array(df_X)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(df_X)
df_X = scaler.transform(df_X)

# %%
df_X
# Out:
# array([[0.66666667, 1.        , 0.58264463, ..., 0.28208745, 0.562217  ,
#         0.43939394],
#        [0.48333333, 0.        , 0.14876033, ..., 0.14104372, 0.22243673,
#         0.16666667],
#        [0.88333333, 1.        , 0.51652893, ..., 0.28208745, 0.49657763,
#         0.40909091],
#        ...,
#        [0.68333333, 1.        , 0.28512397, ..., 0.24964739, 0.30503001,
#         0.56060606],
#        [0.28333333, 0.        , 0.49586777, ..., 0.39351199, 0.65702552,
#         0.40909091],
#        [0.28333333, 0.        , 0.0661157 , ..., 0.14104372, 0.46930394,
#         0.51515152]])

# %% [markdown]
# ## (4) train 데이터와 test 데이터로 분리하기

# %% [markdown]
# - X와 y 데이터를 각각 train 데이터와 test 데이터로 분리해주세요.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df_X, df_y, test_size = 0.3, random_state =23)

print(X_train.shape, X_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (309, 10) (133, 10)
# (309,) (133,)

# %% [markdown]
# ## (5) 모델 준비하기

# %% [markdown]
# - 입력 데이터 개수에 맞는 가중치 W와 b를 준비해주세요.
# - 모델 함수를 구현해주세요.

# %%
np.random.seed(0)
W = np.random.rand(10)
b = np.random.rand()
print(W)
print(b)
# Out:
# [0.5488135  0.71518937 0.60276338 0.54488318 0.4236548  0.64589411
#  0.43758721 0.891773   0.96366276 0.38344152]
# 0.7917250380826646

# %%
def regression_model(X,W,b) :
    y = np.dot(X,W) + b
    return y

# %%
y_hat = regression_model(X_train, W,b)

# %% [markdown]
# ## (6) 손실함수 loss 정의하기

# %% [markdown]
# - 손실함수를 MSE 함수로 정의해주세요.

# %%
def MSE(a,b):
    MSE = ((a - b) ** 2).mean()
    return MSE

# %%
def RMSE(mse):
    return mse**0.5

# %%
MSE(y_hat,y_train)
# Out:
# 27251.158719222138

# %% [markdown]
# ## (7) 기울기를 구하는 gradient 함수 구현하기

# %% [markdown]
# - 기울기를 계산하는 gradient 함수를 구현해주세요.

# %%
def gradient_descent(X,predicted, y) :
    N = len(X)
    dW = 1/N * 2 * X.T.dot(predicted-y)
    db = 2 * (predicted - y).mean()
    return dW, db

# %% [markdown]
# ## (8) 하이퍼 파라미터인 학습률 설정하기

# %% [markdown]
# - 학습률, learning rate 를 설정해주세요
# - 만약 학습이 잘 되지 않는다면 learning rate 값을 한번 여러 가지로 설정하며 실험해 보세요.

# %%
LearningRate = 0.01

# %% [markdown]
# ## (9) 모델 학습하기

# %% [markdown]
# - 정의된 손실함수와 기울기 함수로 모델을 학습해주세요.
# - loss값이 충분히 떨어질 때까지 학습을 진행해주세요.
# - 입력하는 데이터인 X에 들어가는 특성 컬럼들을 몇 개 빼도 괜찮습니다. 다양한 데이터로 실험해 보세요.

# %%
epoch = 2000
losses = []

for i in range(epoch+1) :
    prediction = regression_model(X_train, W, b)
    loss = MSE(y_train ,prediction)
    dW, db = gradient_descent(X_train, prediction, y_train)
    W -= LearningRate * dW
    b -= LearningRate * db
    losses.append(loss)
    
    if i % 100 == 0 :
        print(f'for epoch {i}, loss : {loss}')
# Out:
# for epoch 0, loss : 27251.158719222138
# for epoch 100, loss : 4572.186640612103
# for epoch 200, loss : 4229.724557846721
# for epoch 300, loss : 3983.046348422478
# for epoch 400, loss : 3796.4933590855717
# for epoch 500, loss : 3651.1408676297524
# for epoch 600, loss : 3535.7586655586997
# for epoch 700, loss : 3443.015826450203
# for epoch 800, loss : 3367.7738977944246
# for epoch 900, loss : 3306.258774144508
# for epoch 1000, loss : 3255.6177940580897
# for epoch 1100, loss : 3213.656946152612
# for epoch 1200, loss : 3178.670074537655
# for epoch 1300, loss : 3149.3201537501795
# for epoch 1400, loss : 3124.5530663543022
# for epoch 1500, loss : 3103.5333083232467
# for epoch 1600, loss : 3085.5952946978664
# for epoch 1700, loss : 3070.206134376515
# for epoch 1800, loss : 3056.937000813543
# for epoch 1900, loss : 3045.4410176194647
# for epoch 2000, loss : 3035.436115090029

# %% [markdown]
# ## (10) test 데이터에 대한 성능 확인하기

# %% [markdown]
# - test 데이터에 대한 성능을 확인해주세요.

# %%
test_prediction = regression_model(X_test,W,b)
final_loss = MSE(test_prediction, y_test)
final_loss
# Out:
# 2805.8469526130157

# %%
RMSE(final_loss)
# Out:
# 52.970245917996415

# %% [markdown]
# ## (11) 정답 데이터와 예측한 데이터 시각화하기

# %% [markdown]
# - x축에는 X 데이터의 첫 번째 컬럼을, y축에는 정답인 target 데이터를 넣어서 모델이 예측한 데이터를 시각화해 주세요.

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
plt.scatter(df_X[:,3], df_y)
plt.scatter(df_X[:,3], regression_model(df_X,W,b))

plt.show()

# %% [markdown]
# </br>
# </br>
#
# ---
#
# # 💦⛅️⚡️🚲 프로젝트 2 : 날씨 좋은 월요일 오후 세 시, 자전거 타는 사람은 몇 명?

# %% [markdown]
# - datetime - hourly date + timestamp
# - season -  1 = spring, 2 = summer, 3 = fall, 4 = winter
# - holiday - whether the day is considered a holiday
# - workingday - whether the day is neither a weekend nor holiday
# - weather - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - temp - temperature in Celsius
# - atemp - "feels like" temperature in Celsius
# - humidity - relative humidity
# - windspeed - wind speed
# - casual - number of non-registered user rentals initiated
# - registered - number of registered user rentals initiated
# - count - number of total rentals

# %% [markdown]
# ## (1) 데이터 가져오기

# %% [markdown]
# - 터미널에서 ~/data/data/bike-sharing-demand 경로에 train.csv 데이터를 train 변수로 가져 옵니다.
# - 여기에서 데이터를 상세히 확인할 수 있습니다.

# %%
wdata = pd.read_csv('../train.csv')

# %%
wdata.tail()
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %%
obcol = wdata.dtypes.value_counts()

# %%
flcol = wdata.select_dtypes('float64').columns

# %%
intcol = wdata.select_dtypes('int64').columns

# %%
# one-hot : season, wetaher?
for i in intcol:
    print(wdata[i].value_counts())
# Out:
# 4    2734
# 2    2733
# 3    2733
# 1    2686
# Name: season, dtype: int64
# 0    10575
# 1      311
# Name: holiday, dtype: int64
# 1    7412
# 0    3474
# Name: workingday, dtype: int64
# 1    7192
# 2    2834
# 3     859
# 4       1
# Name: weather, dtype: int64
# 88    368
# 94    324
# 83    316
# 87    289
# 70    259
#      ...
# 8       1
# 10      1
# 97      1
# 96      1
# 91      1
# Name: humidity, Length: 89, dtype: int64
# 0      986
# 1      667
# 2      487
# 3      438
# 4      354
#       ...
# 332      1
# 361      1
# 356      1
# 331      1
# 304      1
# Name: casual, Length: 309, dtype: int64
# 3      195
# 4      190
# 5      177
# 6      155
# 2      150
#       ...
# 570      1
# 422      1
# 678      1
# 565      1
# 636      1
# Name: registered, Length: 731, dtype: int64
# 5      169
# 4      149
# 3      144
# 6      135
# 2      132
#       ...
# 801      1
# 629      1
# 825      1
# 589      1
# 636      1
# Name: count, Length: 822, dtype: int64

# %%
wdata = pd.get_dummies(wdata, columns =['season','weather'])

# %% [markdown]
# ## (2) datetime 컬럼을 datetime 자료형으로 변환하고 연, 월, 일, 시, 분, 초까지 6가지 컬럼 생성하기

# %% [markdown]
# - to_datetime 활용 : 링크 참조
# - pandas datetime extract year month day 키워드로 검색해 보기

# %%
wdata['datetime_new'] = pd.to_datetime(wdata['datetime'])
wdata['datetime_new']
# Out:
# 0       2011-01-01 00:00:00
# 1       2011-01-01 01:00:00
# 2       2011-01-01 02:00:00
# 3       2011-01-01 03:00:00
# 4       2011-01-01 04:00:00
#                 ...
# 10881   2012-12-19 19:00:00
# 10882   2012-12-19 20:00:00
# 10883   2012-12-19 21:00:00
# 10884   2012-12-19 22:00:00
# 10885   2012-12-19 23:00:00
# Name: datetime_new, Length: 10886, dtype: datetime64[ns]

# %%
#연
wdata['year'] = wdata['datetime_new'].map(lambda x : x.year)
#월
wdata['month'] = wdata['datetime_new'].map(lambda x : x.month)
#일
wdata['day'] = wdata['datetime_new'].map(lambda x : x.day)
#시
wdata['hour'] = wdata['datetime_new'].map(lambda x : x.hour)
#분
wdata['min'] = wdata['datetime_new'].map(lambda x : x.minute)
#초
wdata['sec'] = wdata['datetime_new'].map(lambda x : x.second)

# %% [markdown]
# ## (3) year, month, day, hour, minute, second 데이터 개수 시각화하기

# %% [markdown]
# - sns.countplot 활용해서 시각화하기
# - subplot을 활용해서 한 번에 6개의 그래프 함께 시각화하기

# %%
time_col = ['year','month','day','hour','min','sec']

# %%
fig = plt.figure(figsize = (15,6))
for i, col in enumerate(time_col) :
    ax = fig.add_subplot(2,3,i+1)
    sns.countplot(data = wdata, x = col)
    plt.xticks(rotation=45)

plt.suptitle('Countplot by datetime category')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## (4) X, y 컬럼 선택 및 train/test 데이터 분리

# %% [markdown]
# - X(feature) 에는 어떤 데이터 컬럼을 넣어야 될지 고민해 봅시다 데이터 컬럼을 추가하거나 빼면서 잘 조합하여 데이터를 넣기 바랍니다. 만일 모든 데이터 컬럼(특징)을 넣는다면 오차 값이 말도 안 되게 적게 나올 수도 있습니다. ex) count를 예측하는데 casual,registered 컬럼이 필요할까요?
#
# - count 값을 맞추고자 하므로, y 변수에 count 컬럼의 데이터 넣기

# %% [markdown]
# feature = min, sec, registered, casual # count = (registered + casual)
# data

# %%
wdata.corr()['count'].sort_values(ascending=False)
# Out:
# count         1.000000
# registered    0.970948
# casual        0.690414
# hour          0.400601
# temp          0.394454
# atemp         0.389784
# year          0.260403
# month         0.166862
# season_3      0.136942
# weather_1     0.105246
# windspeed     0.101369
# season_2      0.075681
# season_4      0.023704
# day           0.019826
# workingday    0.011594
# weather_4    -0.001459
# holiday      -0.005393
# weather_2    -0.041329
# weather_3    -0.117519
# season_1     -0.237704
# humidity     -0.317371
# min                NaN
# sec                NaN
# Name: count, dtype: float64

# %%
remove_col = ['min','sec','causal','registered', 'count', 'datetime_new', 'datetime']
train_col = list(set(wdata.columns) - set(remove_col))
train_col
# Out:
# ['weather_3',
#  'windspeed',
#  'casual',
#  'humidity',
#  'atemp',
#  'weather_1',
#  'holiday',
#  'temp',
#  'season_4',
#  'day',
#  'season_1',
#  'weather_2',
#  'year',
#  'season_3',
#  'weather_4',
#  'season_2',
#  'workingday',
#  'month',
#  'hour']

# %%
wdata[train_col].corr().style.background_gradient(cmap = 'YlGn')
# Out:
# <style type="text/css">
# #T_e7c8f_row0_col0, #T_e7c8f_row1_col1, #T_e7c8f_row2_col2, #T_e7c8f_row3_col3, #T_e7c8f_row4_col4, #T_e7c8f_row5_col5, #T_e7c8f_row6_col6, #T_e7c8f_row7_col7, #T_e7c8f_row8_col8, #T_e7c8f_row9_col9, #T_e7c8f_row10_col10, #T_e7c8f_row11_col11, #T_e7c8f_row12_col12, #T_e7c8f_row13_col13, #T_e7c8f_row14_col14, #T_e7c8f_row15_col15, #T_e7c8f_row16_col16, #T_e7c8f_row17_col17, #T_e7c8f_row18_col18 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_e7c8f_row0_col1, #T_e7c8f_row6_col0, #T_e7c8f_row6_col3, #T_e7c8f_row9_col0, #T_e7c8f_row15_col1 {
#   background-color: #d0ec9f;
#   color: #000000;
# }
# #T_e7c8f_row0_col2, #T_e7c8f_row11_col18 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_e7c8f_row0_col3, #T_e7c8f_row7_col5 {
#   background-color: #7ec97b;
#   color: #000000;
# }
# #T_e7c8f_row0_col4, #T_e7c8f_row1_col17 {
#   background-color: #b9e294;
#   color: #000000;
# }
# #T_e7c8f_row0_col5, #T_e7c8f_row0_col18, #T_e7c8f_row3_col15, #T_e7c8f_row7_col1, #T_e7c8f_row12_col1 {
#   background-color: #def2a7;
#   color: #000000;
# }
# #T_e7c8f_row0_col6, #T_e7c8f_row2_col8 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_e7c8f_row0_col7, #T_e7c8f_row5_col2 {
#   background-color: #b8e293;
#   color: #000000;
# }
# #T_e7c8f_row0_col8, #T_e7c8f_row0_col15, #T_e7c8f_row14_col2 {
#   background-color: #d7efa2;
#   color: #000000;
# }
# #T_e7c8f_row0_col9, #T_e7c8f_row2_col16, #T_e7c8f_row3_col1, #T_e7c8f_row3_col2, #T_e7c8f_row3_col12, #T_e7c8f_row3_col18, #T_e7c8f_row4_col14, #T_e7c8f_row5_col0, #T_e7c8f_row5_col3, #T_e7c8f_row5_col11, #T_e7c8f_row5_col14, #T_e7c8f_row6_col9, #T_e7c8f_row7_col14, #T_e7c8f_row8_col13, #T_e7c8f_row8_col15, #T_e7c8f_row10_col4, #T_e7c8f_row10_col7, #T_e7c8f_row10_col8, #T_e7c8f_row10_col13, #T_e7c8f_row10_col15, #T_e7c8f_row10_col17, #T_e7c8f_row11_col5, #T_e7c8f_row13_col8, #T_e7c8f_row13_col15, #T_e7c8f_row15_col8, #T_e7c8f_row15_col13, #T_e7c8f_row16_col6, #T_e7c8f_row17_col10, #T_e7c8f_row17_col14 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_e7c8f_row0_col10, #T_e7c8f_row0_col17, #T_e7c8f_row1_col11, #T_e7c8f_row6_col17, #T_e7c8f_row7_col11, #T_e7c8f_row8_col5, #T_e7c8f_row9_col10, #T_e7c8f_row12_col17, #T_e7c8f_row16_col10, #T_e7c8f_row16_col17 {
#   background-color: #97d385;
#   color: #000000;
# }
# #T_e7c8f_row0_col11, #T_e7c8f_row6_col4, #T_e7c8f_row15_col2 {
#   background-color: #b3e091;
#   color: #000000;
# }
# #T_e7c8f_row0_col12 {
#   background-color: #fcfed6;
#   color: #000000;
# }
# #T_e7c8f_row0_col13, #T_e7c8f_row4_col3, #T_e7c8f_row8_col10, #T_e7c8f_row10_col16, #T_e7c8f_row12_col16, #T_e7c8f_row13_col10, #T_e7c8f_row15_col10, #T_e7c8f_row17_col16 {
#   background-color: #dcf1a5;
#   color: #000000;
# }
# #T_e7c8f_row0_col14, #T_e7c8f_row6_col14, #T_e7c8f_row9_col14 {
#   background-color: #feffe1;
#   color: #000000;
# }
# #T_e7c8f_row0_col16, #T_e7c8f_row7_col0 {
#   background-color: #d2eda0;
#   color: #000000;
# }
# #T_e7c8f_row1_col0, #T_e7c8f_row13_col3 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_e7c8f_row1_col2, #T_e7c8f_row1_col4, #T_e7c8f_row4_col18, #T_e7c8f_row17_col2 {
#   background-color: #bee596;
#   color: #000000;
# }
# #T_e7c8f_row1_col3 {
#   background-color: #fcfed7;
#   color: #000000;
# }
# #T_e7c8f_row1_col5, #T_e7c8f_row12_col11, #T_e7c8f_row17_col11 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_e7c8f_row1_col6, #T_e7c8f_row2_col12, #T_e7c8f_row11_col1, #T_e7c8f_row12_col6 {
#   background-color: #e3f4aa;
#   color: #000000;
# }
# #T_e7c8f_row1_col7, #T_e7c8f_row2_col15, #T_e7c8f_row3_col8 {
#   background-color: #b6e192;
#   color: #000000;
# }
# #T_e7c8f_row1_col8, #T_e7c8f_row8_col2, #T_e7c8f_row10_col6 {
#   background-color: #e7f6ad;
#   color: #000000;
# }
# #T_e7c8f_row1_col9, #T_e7c8f_row6_col16, #T_e7c8f_row7_col8 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_e7c8f_row1_col10, #T_e7c8f_row3_col0 {
#   background-color: #77c679;
#   color: #000000;
# }
# #T_e7c8f_row1_col12, #T_e7c8f_row17_col15 {
#   background-color: #fbfed0;
#   color: #000000;
# }
# #T_e7c8f_row1_col13, #T_e7c8f_row8_col1 {
#   background-color: #eaf7af;
#   color: #000000;
# }
# #T_e7c8f_row1_col14, #T_e7c8f_row3_col9 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_e7c8f_row1_col15, #T_e7c8f_row14_col3, #T_e7c8f_row15_col17 {
#   background-color: #ceeb9e;
#   color: #000000;
# }
# #T_e7c8f_row1_col16, #T_e7c8f_row5_col1, #T_e7c8f_row9_col8, #T_e7c8f_row9_col13, #T_e7c8f_row9_col15, #T_e7c8f_row15_col3, #T_e7c8f_row15_col16, #T_e7c8f_row16_col1 {
#   background-color: #d9f0a3;
#   color: #000000;
# }
# #T_e7c8f_row1_col18, #T_e7c8f_row3_col4, #T_e7c8f_row3_col10 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_e7c8f_row2_col0, #T_e7c8f_row11_col2, #T_e7c8f_row11_col6, #T_e7c8f_row11_col13, #T_e7c8f_row12_col18, #T_e7c8f_row17_col18 {
#   background-color: #e2f4aa;
#   color: #000000;
# }
# #T_e7c8f_row2_col1 {
#   background-color: #c4e799;
#   color: #000000;
# }
# #T_e7c8f_row2_col3, #T_e7c8f_row5_col9, #T_e7c8f_row8_col9, #T_e7c8f_row10_col9, #T_e7c8f_row13_col9, #T_e7c8f_row14_col9 {
#   background-color: #feffdf;
#   color: #000000;
# }
# #T_e7c8f_row2_col4, #T_e7c8f_row2_col7 {
#   background-color: #39a056;
#   color: #f1f1f1;
# }
# #T_e7c8f_row2_col5 {
#   background-color: #70c275;
#   color: #000000;
# }
# #T_e7c8f_row2_col6, #T_e7c8f_row8_col16, #T_e7c8f_row13_col16, #T_e7c8f_row14_col1 {
#   background-color: #ddf1a6;
#   color: #000000;
# }
# #T_e7c8f_row2_col9, #T_e7c8f_row7_col9, #T_e7c8f_row10_col14 {
#   background-color: #fdfeda;
#   color: #000000;
# }
# #T_e7c8f_row2_col10, #T_e7c8f_row8_col0, #T_e7c8f_row15_col0 {
#   background-color: #c9e99c;
#   color: #000000;
# }
# #T_e7c8f_row2_col11, #T_e7c8f_row5_col17, #T_e7c8f_row14_col17, #T_e7c8f_row17_col3 {
#   background-color: #9ad587;
#   color: #000000;
# }
# #T_e7c8f_row2_col13 {
#   background-color: #a6da8b;
#   color: #000000;
# }
# #T_e7c8f_row2_col14, #T_e7c8f_row8_col14, #T_e7c8f_row11_col14, #T_e7c8f_row13_col14, #T_e7c8f_row15_col14 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_e7c8f_row2_col17, #T_e7c8f_row4_col5, #T_e7c8f_row13_col5, #T_e7c8f_row15_col7, #T_e7c8f_row18_col2 {
#   background-color: #7fc97c;
#   color: #000000;
# }
# #T_e7c8f_row2_col18, #T_e7c8f_row16_col11, #T_e7c8f_row18_col7 {
#   background-color: #8bce81;
#   color: #000000;
# }
# #T_e7c8f_row3_col5, #T_e7c8f_row5_col15, #T_e7c8f_row5_col18, #T_e7c8f_row6_col1, #T_e7c8f_row9_col16, #T_e7c8f_row11_col15, #T_e7c8f_row12_col8, #T_e7c8f_row12_col13, #T_e7c8f_row12_col15, #T_e7c8f_row14_col8, #T_e7c8f_row14_col13, #T_e7c8f_row14_col15, #T_e7c8f_row14_col16, #T_e7c8f_row18_col8, #T_e7c8f_row18_col13, #T_e7c8f_row18_col15 {
#   background-color: #daf0a4;
#   color: #000000;
# }
# #T_e7c8f_row3_col6, #T_e7c8f_row7_col6, #T_e7c8f_row17_col6, #T_e7c8f_row18_col6 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_e7c8f_row3_col7 {
#   background-color: #c1e698;
#   color: #000000;
# }
# #T_e7c8f_row3_col11, #T_e7c8f_row7_col17 {
#   background-color: #56b568;
#   color: #f1f1f1;
# }
# #T_e7c8f_row3_col13 {
#   background-color: #c7e89a;
#   color: #000000;
# }
# #T_e7c8f_row3_col14, #T_e7c8f_row12_col14, #T_e7c8f_row18_col14 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_e7c8f_row3_col16 {
#   background-color: #ddf2a6;
#   color: #000000;
# }
# #T_e7c8f_row3_col17 {
#   background-color: #64bc6f;
#   color: #f1f1f1;
# }
# #T_e7c8f_row4_col0, #T_e7c8f_row6_col8, #T_e7c8f_row6_col13, #T_e7c8f_row9_col1, #T_e7c8f_row9_col2, #T_e7c8f_row12_col0 {
#   background-color: #d3eda0;
#   color: #000000;
# }
# #T_e7c8f_row4_col1, #T_e7c8f_row4_col6, #T_e7c8f_row5_col6, #T_e7c8f_row14_col6 {
#   background-color: #e6f5ac;
#   color: #000000;
# }
# #T_e7c8f_row4_col2 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_e7c8f_row4_col7, #T_e7c8f_row7_col4 {
#   background-color: #00472a;
#   color: #f1f1f1;
# }
# #T_e7c8f_row4_col8, #T_e7c8f_row17_col12, #T_e7c8f_row18_col12 {
#   background-color: #fbfdce;
#   color: #000000;
# }
# #T_e7c8f_row4_col9, #T_e7c8f_row11_col9, #T_e7c8f_row16_col9 {
#   background-color: #fdfedb;
#   color: #000000;
# }
# #T_e7c8f_row4_col10 {
#   background-color: #f8fdc1;
#   color: #000000;
# }
# #T_e7c8f_row4_col11, #T_e7c8f_row9_col17, #T_e7c8f_row11_col10, #T_e7c8f_row12_col10, #T_e7c8f_row18_

# %%
wdata[train_col].describe()
# Out:
#           weather_3     windspeed        casual      humidity         atemp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean       0.078909     12.799395     36.021955     61.886460     23.655084
# std        0.269609      8.164537     49.960477     19.245033      8.474601
# min        0.000000      0.000000      0.000000      0.000000      0.760000
# 25%        0.000000      7.001500      4.000000     47.000000     16.665000
# 50%        0.000000     12.998000     17.000000     62.000000     24.240000
# 75%        0.000000     16.997900     49.000000     77.000000     31.060000
# max        1.000000     56.996900    367.000000    100.000000     45.455000
#
#           weather_1       holiday         temp      season_4           day  \
# count  10886.000000  10886.000000  10886.00000  10886.000000  10886.000000
# mean       0.660665      0.028569     20.23086      0.251148      9.992559
# std        0.473505      0.166599      7.79159      0.433694      5.476608
# min        0.000000      0.000000      0.82000      0.000000      1.000000
# 25%        0.000000      0.000000     13.94000      0.000000      5.000000
# 50%        1.000000      0.000000     20.50000      0.000000     10.000000
# 75%        1.000000      0.000000     26.24000      1.000000     15.000000
# max        1.000000      1.000000     41.00000      1.000000     19.000000
#
#            season_1     weather_2          year      season_3     weather_4  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean       0.246739      0.260334   2011.501929      0.251056      0.000092
# std        0.431133      0.438837      0.500019      0.433641      0.009584
# min        0.000000      0.000000   2011.000000      0.000000      0.000000
# 25%        0.000000      0.000000   2011.000000      0.000000      0.000000
# 50%        0.000000      0.000000   2012.000000      0.000000      0.000000
# 75%        0.000000      1.000000   2012.000000      1.000000      0.000000
# max        1.000000      1.000000   2012.000000      1.000000      1.000000
#
#            season_2    workingday         month          hour
# count  10886.000000  10886.000000  10886.000000  10886.000000
# mean       0.251056      0.680875      6.521495     11.541613
# std        0.433641      0.466159      3.444373      6.915838
# min        0.000000      0.000000      1.000000      0.000000
# 25%        0.000000      0.000000      4.000000      6.000000
# 50%        0.000000      1.000000      7.000000     12.000000
# 75%        1.000000      1.000000     10.000000     18.000000
# max        1.000000      1.000000     12.000000     23.000000

# %%
X = wdata[train_col].values
y = wdata['count'].values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 23 )

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (7620, 19) (3266, 19)
# (7620,) (3266,)

# %% [markdown]
# ## (5) LinearRegression 모델 학습

# %% [markdown]
# - sklearn의 LinearRegression 모델 불러오기 및 학습하기

# %%
from sklearn.linear_model import LinearRegression

# %%
linearmodel = LinearRegression()
linearmodel.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## (6) 학습된 모델로 X_test에 대한 예측값 출력 및 손실함수값 계산

# %%
from sklearn.metrics import mean_squared_error

# %%
prediction = linearmodel.predict(X_test)
mse = mean_squared_error(y_test, prediction)
rmse = mse ** 0.5
print('mse : ',mse,'rmse : ', rmse)
# Out:
# mse :  13100.500727189223 rmse :  114.45741883857605

# %% [markdown]
# - 학습된 모델에 X_test를 입력해서 예측값 출력하기
# - 모델이 예측한 값과 정답 target 간의 손실함수 값 계산하기
# - mse 값과 함께 rmse 값도 계산하기

# %% [markdown]
# ## (7) x축은 temp 또는 humidity로, y축은 count로 예측 결과 시각화하기

# %% [markdown]
# - x축에 X 데이터 중 temp 데이터를, y축에는 count 데이터를 넣어서 시각화하기
# - x축에 X 데이터 중 humidity 데이터를, y축에는 count 데이터를 넣어서 시각화하기

# %%
train_col
# Out:
# ['weather_3',
#  'windspeed',
#  'casual',
#  'humidity',
#  'atemp',
#  'weather_1',
#  'holiday',
#  'temp',
#  'season_4',
#  'day',
#  'season_1',
#  'weather_2',
#  'year',
#  'season_3',
#  'weather_4',
#  'season_2',
#  'workingday',
#  'month',
#  'hour']

# %%
hindx = train_col.index('humidity')

# %%
tindx = train_col.index('temp')

# %%
final_y = linearmodel.predict(X)

# %%
fig = plt.figure(figsize = (12,6) )

ax = fig.add_subplot(1,2,1)
plt.scatter(X[:,hindx], y, label = 'true')
plt.scatter(X[:,hindx], final_y, label = 'predicted')
plt.xlabel('humidity')
plt.ylabel('count')
plt.legend()

ax2 = fig.add_subplot(1,2,2)
plt.scatter(X[:,tindx], y, label = 'true')
plt.scatter(X[:,tindx], final_y, label = 'predicted')
plt.xlabel('temp')
plt.ylabel('count')
plt.legend()

plt.suptitle('True vs Predicted')
plt.tight_layout()

plt.show()
