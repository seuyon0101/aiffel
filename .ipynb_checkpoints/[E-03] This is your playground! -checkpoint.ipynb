# %% [markdown]
# # 프로젝트 : This is your playground! Leaderboard를 정복해 주세요!

# %%
import xgboost
import lightgbm
import missingno
import sklearn

print(xgboost.__version__)
print(lightgbm.__version__)
print(missingno.__version__)
print(sklearn.__version__)
# Out:
# 1.6.2
# 3.2.1
# 0.5.1
# 1.1.1

# %% [markdown]
# ## ✓ 튜닝해볼 수 있는 모델 클래스 인자

# %% [markdown]
# 대표적으로 자주 튜닝하는 lightgbm 라이브러리의 인자는 다음과 같습니다.
#
# - max_depth : 의사 결정 나무의 깊이, 정수 사용
# - learning_rate : 한 스텝에 이동하는 양을 결정하는 파라미터, 보통 0.0001~0.1 사이의 실수 사용
# - n_estimators : 사용하는 개별 모델의 개수, 보통 50~100 이상의 정수 사용
# - num_leaves : 하나의 LightGBM 트리가 가질 수 있는 최대 잎의 수
# - boosting_type : 부스팅 방식, gbdt, rf 등의 문자열 입력
#
# 위에서 저는 n_estimators와 max_depth 에 대해서만 아주 간단하게 실험했지만, 훨씬 더 다양하게 실험을 하며 최적의 조합을 찾아볼 수 있습니다.
#
#
# 실제로 lightgbm에 넣을 수 있는 인자는 아래 자료들에서 설명하는 것처럼 매우 다양합니다.
#
# - lightGBM / XGBoost 파라미터 설명
# - Chapter 4. 분류 - LightGBM
#
# 위의 자료 외에도 lightgbm, xgboost 하이퍼 파라미터 튜닝 키워드로 검색해보면 다양한 하이퍼 파라미터의 종류를 확인할 수 있습니다.
#
# 실험 과정에서는 물론 위에서 만들었던 my_GridSearch(), save_submission() 등의 함수를 사용해도 되고, 혹은 여러분이 원하는 새로운 함수를 만들어서 사용해도 됩니다!

# %% [markdown]
# ## ✓ 시도해볼 수 있는 방법

# %% [markdown]
# 여러분이 시도해볼 수 있는 방법은 다음과 같은 것들이 있습니다.
#
# - 기존에 있는 데이터의 피처를 모델을 보다 잘 표현할 수 있는 형태로 처리하기 (피처 엔지니어링)
# - LGBMRegressor, XGBRegressor, RandomForestRegressor 세 가지 이상의 다양한 모델에 대해 하이퍼 파라미터 튜닝하기
# - 다양한 하이퍼 파라미터에 대해 그리드 탐색을 시도해서 최적의 조합을 찾아보기
# - Baseline 커널에서 활용했던 블렌딩 방법 활용하기
#
# 물론 이 외에도 좋은 아이디어가 있다면 당연히 시도해보는 것도 좋습니다.
#
# 자유롭게 여러 가지 방법을 활용해서 점수를 끌어올려 보세요!
#
#
# 참고로, 진행하면서 도움이 될 수 있는 가장 좋은 자료는 이미 대회를 진행한 사람들이 올려둔 커널입니다.
#
# - https://www.kaggle.com/c/2019-2nd-ml-month-with-kakr/notebooks
#
#
# 아주 다양하게 데이터를 탐색해 본 커널도 있고, 상위권을 달성한 커널은 오늘 다루지 않은 스태킹 앙상블(stacking ensemble) 등의 기법을 활용한 커널을 활용하기도 합니다.
#
# 한 번씩 구경해보고 다른 사람들은 어떤 전략으로 성능을 끌어올렸는지 공부해보는 것도 매우 좋을 겁니다!
#
# 여러 가지 실험을 해보고 결과 csv는 캐글에, 사용한 노트북은 깃허브(GitHub)를 통해 이곳에 제출해 주세요.
#
# ```제출한 노트북에는 본인의 캐글 Submission 스코어를 기재해 주시기 바랍니다```.
#
#
#
# 그럼, 시작해보죠! 화이팅!!! 💪🏼

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
project_path = os.getenv('HOME') + '/Desktop/house_prices'

# %%
training_path = project_path + '/train.csv'
test_path = project_path + '/test.csv'

# %% [markdown]
# ## Baseline

# %%
X =  pd.read_csv(training_path)
y = X.price
del X['id']
del X['price']
X['date'] = X['date'].apply(lambda x : x[:6]).astype(int)
X = X.values

# %%
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.metrics import mean_squared_error

# %%
model = lgb.LGBMRegressor()

# %%
def get_score(model, X,y, random_state=2022, test_size = .2) :
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = random_state, test_size=test_size)
    model = model
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)

    mse = mean_squared_error(y_test, prediction)
    return mse ** 0.5

# %%
get_score(model, X,y)
# Out:
# 129853.26965916483

# %% [markdown]
# # EDA

# %%
df = pd.read_csv(training_path)

# %%
df.head()
# Out:
#    id             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0   0  20141013T000000  221900.0         3       1.00         1180      5650
# 1   1  20150225T000000  180000.0         2       1.00          770     10000
# 2   2  20150218T000000  510000.0         3       2.00         1680      8080
# 3   3  20140627T000000  257500.0         3       2.25         1715      6819
# 4   4  20150115T000000  291850.0         3       1.50         1060      9711
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     1.0           0     0  ...      6         770              0      1933
# 2     1.0           0     0  ...      8        1680              0      1987
# 3     2.0           0     0  ...      7        1715              0      1995
# 4     1.0           0     0  ...      7        1060              0      1963
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1             0    98028  47.7379 -122.233           2720        8062
# 2             0    98074  47.6168 -122.045           1800        7503
# 3             0    98003  47.3097 -122.327           2238        6819
# 4             0    98198  47.4095 -122.315           1650        9711
#
# [5 rows x 21 columns]

# %%
missingno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes.value_counts()
# Out:
# int64      15
# float64     5
# object      1
# dtype: int64

# %%
col_int64 = [df.dtypes.index[i] for i in range(len(df.dtypes)) if df.dtypes[i] == 'int64']
col_float64 = [df.dtypes.index[i] for i in range(len(df.dtypes)) if df.dtypes[i] == 'float64']
col_object = [df.dtypes.index[i] for i in range(len(df.dtypes)) if df.dtypes[i] == 'object']

print('col_int64 : ', col_int64)
print('col_float64 : ', col_float64)
print('col_object : ', col_object)
# Out:
# col_int64 :  ['id', 'bedrooms', 'sqft_living', 'sqft_lot', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'sqft_living15', 'sqft_lot15']
# col_float64 :  ['price', 'bathrooms', 'floors', 'lat', 'long']
# col_object :  ['date']

# %%
col_int64.remove('id')
col_float64.remove('price')

# %% [markdown]
# Data fields
#
# - ID : 집을 구분하는 번호 `#flag`
# - date : 집을 구매한 날짜 `#flag`
# - price : 집의 가격(Target variable)
# - bedrooms : 침실의 수
# - bathrooms : 화장실의 수
# - sqft_living : 주거 공간의 평방 피트(면적)
# - sqft_lot : 부지의 평방 피트(면적)
# - floors : 집의 층 수
# - waterfront : 집의 전방에 강이 흐르는지 유무 (a.k.a. 리버뷰)
# - view : 집이 얼마나 좋아 보이는지의 정도
# - condition : 집의 전반적인 상태
# - grade : King County grading 시스템 기준으로 매긴 집의 등급
# - sqft_above : 지하실을 제외한 평방 피트(면적)
# - sqft_basement : 지하실의 평방 피트(면적)
# - yr_built : 지어진 년도 #flag : date?
# - yr_renovated : 집을 재건축한 년도
# - zipcode : 우편번호 `#flag` 오히려 이게 위도 경도 보다 낳을듯
# - lat : 위도 `#flag`
# - long : 경도 `#flag`
# - sqft_living15 : 2015년 기준 주거 공간의 평방 피트(면적, 집을 재건축했다면, 변화가 있을 수 있음)
# - sqft_lot15 : 2015년 기준 부지의 평방 피트(면적, 집을 재건축했다면, 변화가 있을 수 있음)

# %% [markdown]
# HIGH CORR :
#
# - sqft_living & sqft_above(0.88)

# %%
df.corr().style.background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_5618d_row0_col0, #T_5618d_row1_col1, #T_5618d_row2_col2, #T_5618d_row3_col3, #T_5618d_row4_col4, #T_5618d_row5_col5, #T_5618d_row6_col6, #T_5618d_row7_col7, #T_5618d_row8_col8, #T_5618d_row9_col9, #T_5618d_row10_col10, #T_5618d_row11_col11, #T_5618d_row12_col12, #T_5618d_row13_col13, #T_5618d_row14_col14, #T_5618d_row15_col15, #T_5618d_row16_col16, #T_5618d_row17_col17, #T_5618d_row18_col18, #T_5618d_row19_col19 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_5618d_row0_col1, #T_5618d_row6_col7, #T_5618d_row8_col0, #T_5618d_row9_col3 {
#   background-color: #fbfdce;
#   color: #000000;
# }
# #T_5618d_row0_col2, #T_5618d_row0_col12, #T_5618d_row2_col19, #T_5618d_row3_col16, #T_5618d_row7_col19, #T_5618d_row15_col8 {
#   background-color: #f1fab5;
#   color: #000000;
# }
# #T_5618d_row0_col3, #T_5618d_row5_col10, #T_5618d_row6_col0, #T_5618d_row19_col10 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# #T_5618d_row0_col4, #T_5618d_row1_col19, #T_5618d_row10_col14, #T_5618d_row18_col9 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_5618d_row0_col5, #T_5618d_row9_col11, #T_5618d_row13_col12 {
#   background-color: #fafdc8;
#   color: #000000;
# }
# #T_5618d_row0_col6, #T_5618d_row5_col11, #T_5618d_row12_col1, #T_5618d_row18_col12 {
#   background-color: #b5e092;
#   color: #000000;
# }
# #T_5618d_row0_col7 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_5618d_row0_col8, #T_5618d_row12_col0 {
#   background-color: #fcfed6;
#   color: #000000;
# }
# #T_5618d_row0_col9, #T_5618d_row3_col5, #T_5618d_row8_col19, #T_5618d_row11_col15, #T_5618d_row13_col19 {
#   background-color: #e7f6ad;
#   color: #000000;
# }
# #T_5618d_row0_col10, #T_5618d_row8_col13, #T_5618d_row14_col3 {
#   background-color: #dff3a8;
#   color: #000000;
# }
# #T_5618d_row0_col11, #T_5618d_row7_col14, #T_5618d_row19_col9 {
#   background-color: #d5eea1;
#   color: #000000;
# }
# #T_5618d_row0_col13, #T_5618d_row1_col6, #T_5618d_row8_col15 {
#   background-color: #9cd687;
#   color: #000000;
# }
# #T_5618d_row0_col14, #T_5618d_row11_col12, #T_5618d_row16_col13 {
#   background-color: #f0f9b4;
#   color: #000000;
# }
# #T_5618d_row0_col15, #T_5618d_row2_col1, #T_5618d_row2_col6, #T_5618d_row19_col18 {
#   background-color: #b3e091;
#   color: #000000;
# }
# #T_5618d_row0_col16, #T_5618d_row8_col16, #T_5618d_row14_col7, #T_5618d_row19_col8 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_5618d_row0_col17, #T_5618d_row12_col18 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_5618d_row0_col18 {
#   background-color: #ddf1a6;
#   color: #000000;
# }
# #T_5618d_row0_col19, #T_5618d_row6_col8 {
#   background-color: #f9fdc2;
#   color: #000000;
# }
# #T_5618d_row1_col0, #T_5618d_row9_col5, #T_5618d_row9_col8, #T_5618d_row14_col5, #T_5618d_row14_col13 {
#   background-color: #f8fcbe;
#   color: #000000;
# }
# #T_5618d_row1_col2, #T_5618d_row3_col12 {
#   background-color: #9ad587;
#   color: #000000;
# }
# #T_5618d_row1_col3, #T_5618d_row18_col1 {
#   background-color: #49af61;
#   color: #f1f1f1;
# }
# #T_5618d_row1_col4, #T_5618d_row3_col11 {
#   background-color: #228343;
#   color: #f1f1f1;
# }
# #T_5618d_row1_col5, #T_5618d_row2_col14, #T_5618d_row19_col6 {
#   background-color: #e6f5ac;
#   color: #000000;
# }
# #T_5618d_row1_col7, #T_5618d_row9_col17 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_5618d_row1_col8, #T_5618d_row6_col17 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_5618d_row1_col9, #T_5618d_row6_col1, #T_5618d_row10_col8 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_5618d_row1_col10 {
#   background-color: #2a8d49;
#   color: #f1f1f1;
# }
# #T_5618d_row1_col11 {
#   background-color: #31974f;
#   color: #f1f1f1;
# }
# #T_5618d_row1_col12 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_5618d_row1_col13, #T_5618d_row6_col2, #T_5618d_row7_col1, #T_5618d_row8_col9 {
#   background-color: #c7e89a;
#   color: #000000;
# }
# #T_5618d_row1_col14, #T_5618d_row2_col9, #T_5618d_row11_col19, #T_5618d_row12_col10 {
#   background-color: #c9e99c;
#   color: #000000;
# }
# #T_5618d_row1_col15, #T_5618d_row8_col3, #T_5618d_row10_col12, #T_5618d_row17_col10, #T_5618d_row18_col8 {
#   background-color: #bee596;
#   color: #000000;
# }
# #T_5618d_row1_col16, #T_5618d_row12_col9 {
#   background-color: #a4d98a;
#   color: #000000;
# }
# #T_5618d_row1_col17, #T_5618d_row7_col15 {
#   background-color: #acdd8e;
#   color: #000000;
# }
# #T_5618d_row1_col18 {
#   background-color: #359c53;
#   color: #f1f1f1;
# }
# #T_5618d_row2_col0 {
#   background-color: #f8fdc1;
#   color: #000000;
# }
# #T_5618d_row2_col3, #T_5618d_row3_col6 {
#   background-color: #47ae60;
#   color: #f1f1f1;
# }
# #T_5618d_row2_col4, #T_5618d_row3_col18 {
#   background-color: #379e54;
#   color: #f1f1f1;
# }
# #T_5618d_row2_col5, #T_5618d_row4_col7, #T_5618d_row5_col1, #T_5618d_row5_col8, #T_5618d_row9_col18, #T_5618d_row12_col19 {
#   background-color: #f3fab6;
#   color: #000000;
# }
# #T_5618d_row2_col7 {
#   background-color: #fdfeda;
#   color: #000000;
# }
# #T_5618d_row2_col8 {
#   background-color: #f2fab5;
#   color: #000000;
# }
# #T_5618d_row2_col10 {
#   background-color: #83cb7d;
#   color: #000000;
# }
# #T_5618d_row2_col11 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_5618d_row2_col12, #T_5618d_row2_col17 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_5618d_row2_col13 {
#   background-color: #a9db8c;
#   color: #000000;
# }
# #T_5618d_row2_col15, #T_5618d_row7_col4, #T_5618d_row14_col12, #T_5618d_row16_col9, #T_5618d_row17_col2 {
#   background-color: #d7efa2;
#   color: #000000;
# }
# #T_5618d_row2_col16, #T_5618d_row9_col14, #T_5618d_row14_col19 {
#   background-color: #f7fcb9;
#   color: #000000;
# }
# #T_5618d_row2_col18 {
#   background-color: #69bf72;
#   color: #000000;
# }
# #T_5618d_row3_col0, #T_5618d_row6_col14, #T_5618d_row8_col5, #T_5618d_row16_col3, #T_5618d_row17_col9, #T_5618d_row18_col14, #T_5618d_row18_col15 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_5618d_row3_col1, #T_5618d_row6_col10 {
#   background-color: #62bb6e;
#   color: #f1f1f1;
# }
# #T_5618d_row3_col2, #T_5618d_row13_col6 {
#   background-color: #4eb163;
#   color: #f1f1f1;
# }
# #T_5618d_row3_col4, #T_5618d_row11_col18 {
#   background-color: #167a3f;
#   color: #f1f1f1;
# }
# #T_5618d_row3_col7, #T_5618d_row12_col7, #T_5618d_row17_col0 {
#   background-color: #f8fcc0;
#   color: #000000;
# }
# #T_5618d_row3_col8, #T_5618d_row5_col3, #T_5618d_row16_col6, #T_5618d_row18_col5, #T_5618d_row19_col3 {
#   background-color: #dbf1a4;
#   color: #000000;
# }
# #T_5618d_row3_col9, #T_5618d_row5_col14, #T_5618d_row6_col16, #T_5618d_row18_col16, #T_5618d_row19_col14 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_5618d_row3_col10, #T_5618d_row4_col1 {
#   background-color: #2b8e4a;
#   color: #f1f1f1;
# }
# #T_5618d_row3_col13 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_5618d_row3_col14, #T_5618d_row4_col14, #T_5618d_row4_col15, #T_5618d_row7_col3, #T_5618d_row7_col6, #T_5618d_row7_col10, #T_5618d_row8_col6, #T_5618d_row10_col16, #T_5618d_row10_col19, #T_5618d_row15_col14 {
#   background-color: #ddf2a6;
#   color: #000000;
# }
# #T_5618d_row3_col15, #T_5618d_row4_col9, #T_5618d_row11_col8, #T_5618d_row12_col16, #T_5618d_row14_col11 {
#   background-color: #def2a7;
#   color: #000000;
# }
# #T_5618d_row3_col17, #T_5618d_row5_col17, #T_5618d_row18_col13 {
#   background-color: #75c578;
#   color: #000000;
# }
# #T_5618d_row3_col19, #T_5618d_row11_col14, #T_5618d_row16_col11, #T_5618d_row16_col14 {
#   background-color: #e4f4ab;
#   color: #000000;
# }
# #T_5618d_row4_col0, #T_5618d_row12_col5, #T_5618d_row16_col2, #T_5618d_row19_col1 {
#   background-color: #f6fcb8;
#   color: #000000;
# }
# #T_5618d_row4_col2 {
#   background-color: #3aa257;
#   color: #f1f1f1;
# }
# #T_5618d_row4_col3, #T_5618d_row4_col10, #T_5618d_row11_col10, #T_5618d_row18_col4 {
#   background-color: #15793e;
#   color: #f1f1f1;
# }
# #T_5618d_row4_col5, #T_5618d_row7_col11, #T_5618d_row12_col17 {
#   background-color: #d2eda0;
#   color: #000000;
# }
# #T_5618d_row4_col6 {
#   background-color: #7ac77a;
#   color: #000000;
# }
# #T_5618d_row4_col8, #T_5618d_row5_col18 {
#   background-color: #bde496;
#   color: #000000;
# }
# #T_5618d_row4_col11 {
#   background-color: #005f34;
#   color: #f1f1f1;
# }
# #T_5618d_row4_col12 {
#   background-color: #64bc6f;
#   color: #f1

# %% [markdown]
# ## id

# %%
#TODO : TEST DATA
train_id = df['id']
del df['id']
train_id
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 15030    15030
# 15031    15031
# 15032    15032
# 15033    15033
# 15034    15034
# Name: id, Length: 15035, dtype: int64

# %% [markdown]
# ## price

# %%
#TODO TEST DATA
y = df['price']

# %%
y.describe()
# Out:
# count    1.503500e+04
# mean     5.406827e+05
# std      3.715247e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
sns.kdeplot(y)
# sns.histplot(y)
plt.show()

# %%
df[['price']+col_float64].corr()['price'].sort_values(ascending=False)
# Out:
# price        1.000000
# bathrooms    0.525479
# lat          0.301604
# floors       0.262588
# long         0.023547
# Name: price, dtype: float64

# %%
df[['price']+ col_int64].corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702899
# grade            0.667211
# sqft_above       0.608577
# sqft_living15    0.586419
# view             0.400806
# bedrooms         0.323672
# sqft_basement    0.322218
# waterfront       0.265738
# yr_renovated     0.140808
# sqft_lot         0.096793
# sqft_lot15       0.086384
# yr_built         0.047290
# condition        0.039740
# zipcode         -0.051498
# Name: price, dtype: float64

# %% [markdown]
# ## date

# %%
# TODO : TEST DATA 
df['date'] = df['date'].apply(lambda x : x[:6]).astype(int)
# df['year'] = df['date'].apply(lambda x : str(x)[:4]).astype(int)

# %%
df.date.describe()
# Out:
# count     15035.000000
# mean     201438.545993
# std          44.252050
# min      201405.000000
# 25%      201407.000000
# 50%      201410.000000
# 75%      201502.000000
# max      201505.000000
# Name: date, dtype: float64

# %% [markdown]
# ## int64 columns

# %%
# col_int64.remove('id')
fig = plt.figure(figsize = (10,15))
for i, col in enumerate(col_int64):
    ax = fig.add_subplot(5,3,i+1)
    sns.kdeplot(data= df, x=col)
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
#check outliers

# %%
data = pd.concat([df['price'], df['sqft_living']], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.regplot(x='sqft_living', y="price", data=data)

# %%
df['sqft_living'].describe()
# Out:
# count    15035.000000
# mean      2083.790223
# std        922.134087
# min        290.000000
# 25%       1430.000000
# 50%       1910.000000
# 75%       2560.000000
# max      13540.000000
# Name: sqft_living, dtype: float64

# %%
drop_index = []
idx = df.loc[df['sqft_living'] > 9000,:].index
df.loc[df['sqft_living'] > 9000,:]
# Out:
#         date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 2775  201406  7062500.0         5       4.50        10040     37325     2.0
# 3134  201408  5570000.0         5       5.75         9200     35069     2.0
# 5108  201410  7700000.0         6       8.00        12050     27600     2.5
# 6469  201409  6885000.0         6       7.75         9890     31374     2.0
# 8912  201405  2280000.0         7       8.00        13540    307752     3.0
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 2775           1     2          3     11        7680           2360      1940
# 3134           0     0          3     13        6200           3000      2001
# 5108           0     3          4     13        8570           3480      1910
# 6469           0     4          3     13        8860           1030      2001
# 8912           0     4          3     12        9410           4130      1999
#
#       yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 2775          2001    98004  47.6500 -122.214           3930       25449
# 3134             0    98039  47.6289 -122.233           3560       24345
# 5108          1987    98102  47.6298 -122.323           3940        8800
# 6469             0    98039  47.6305 -122.240           4540       42730
# 8912             0    98053  47.6675 -121.986           4850      217800

# %%
drop_index.extend(idx)
drop_index
# Out:
# [2775, 3134, 5108, 6469, 8912]

# %% [markdown]
# ### sqrtfoot_above

# %%
data = pd.concat([df['price'], df['sqft_above']], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.regplot(x='sqft_above', y="price", data=data)

# %%
idx = df.loc[df['sqft_above'] > 8000,:].index
drop_index.extend(idx)
df.loc[df['sqft_above'] > 8000,:]
# Out:
#         date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 5108  201410  7700000.0         6       8.00        12050     27600     2.5
# 6469  201409  6885000.0         6       7.75         9890     31374     2.0
# 8912  201405  2280000.0         7       8.00        13540    307752     3.0
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 5108           0     3          4     13        8570           3480      1910
# 6469           0     4          3     13        8860           1030      2001
# 8912           0     4          3     12        9410           4130      1999
#
#       yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 5108          1987    98102  47.6298 -122.323           3940        8800
# 6469             0    98039  47.6305 -122.240           4540       42730
# 8912             0    98053  47.6675 -121.986           4850      217800

# %%
drop_index
# Out:
# [2775, 3134, 5108, 6469, 8912, 5108, 6469, 8912]

# %%
from scipy.stats import skew

# %%
skew2 = {}
for i in col_int64 :
    if (skew(df[i]) < -1) or (skew(df[i]) > 1) :
        skew2[i] = {i:skew(df[i])}

print(skew2.keys())
# Out:
# dict_keys(['sqft_living', 'sqft_lot', 'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement', 'yr_renovated', 'sqft_living15', 'sqft_lot15'])

# %%
skew_col = list(skew2.keys())

# %% [markdown]
# - Symmetric: Values between -0.5 to 0.5
# - Moderated Skewed data: Values between -1 and -0.5 or between 0.5 and 1
# - Highly Skewed data: Values less than -1 or greater than 1
#
# https://medium.com/swlh/skewness-and-kurtosis-in-statistics-a0314c8882d7

# %% [markdown]
# skewness and kurtosis
# https://m.blog.naver.com/yolwooju/222100758577

# %% [markdown]
# ## float64

# %%
fig = plt.figure(figsize = (10,8))
for i, col in enumerate(col_float64):
    ax = fig.add_subplot(2,2,i+1)
    sns.kdeplot(data= df, x=col)
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
box_col = ['bathrooms','bedrooms','floors','view', 'waterfront','grade', 'yr_built'] # min_max

# %%
fig = plt.figure(figsize =(10,12))
for i, col in enumerate(box_col[:6]):
    ax = fig.add_subplot(3,2, i+1)
    sns.boxplot(data = df, x = col, y = 'price')
    plt.title(col)
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.051498
# date             0.007717
# long             0.023547
# condition        0.039740
# yr_built         0.047290
# sqft_lot15       0.086384
# sqft_lot         0.096793
# yr_renovated     0.140808
# floors           0.262588
# waterfront       0.265738
# lat              0.301604
# sqft_basement    0.322218
# bedrooms         0.323672
# view             0.400806
# bathrooms        0.525479
# sqft_living15    0.586419
# sqft_above       0.608577
# grade            0.667211
# sqft_living      0.702899
# price            1.000000
# Name: price, dtype: float64

# %%
len(skew_col) # np.log1p
# Out:
# 10

# %%
len(box_col) #min_max
# Out:
# 10

# %%
#TODO TEST
# remove_col = ['zipcode','lat', 'long']

# %%
all_col = set(df.columns)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df.shape
# Out:
# (15035, 20)

# %%
train = df.copy()
del train['price']

# %%
train.shape
# Out:
# (15035, 19)

# %%
# todo TEST
scaler = MinMaxScaler()
boxdf = pd.DataFrame(train[box_col + ['zipcode','lat','long']])
scaler.fit(boxdf)
boxdf = pd.DataFrame(data = scaler.transform(boxdf), columns = box_col+ ['zipcode','lat','long'])
train.drop(columns =box_col + ['zipcode','lat','long'], inplace=True)
train = pd.concat([train,boxdf], axis=1)
train.head()
train.shape
# Out:
# (15035, 19)

# %%
for i in skew_col :
    train[i] = train[i].apply(lambda x : np.log1p(x))

# %%
# train.drop(columns = remove_col, inplace =True)

# %%
train.drop(index = drop_index, inplace=True)
train.shape
# Out:
# (15030, 19)

# %%
y.drop(index=drop_index, inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(train, y, test_size = .2, random_state=2022)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# %%
random_state= 2022
xgb = XGBRegressor(random_state=random_state)

lgb = LGBMRegressor(max_depth = 6 ,n_estimators = 400, random_state=random_state)
lgb_params = {'n_estimators' : [100,200,300,400], 'max_depth' :[-1,3,6,10]}

rfr = RandomForestRegressor(n_estimators = 300, random_state=random_state)
rfr_params = {'n_estimators' : [100,200,300,400]}

# %%
def search_grid(model, param_grid, X_train, y_train) :
    
    '''
    Returns result table of gridsearched model
    
    arg :
    
    - model : model used to train
    - param_grid : hyper parameters specified in dictionary type
    - X_train : training dataset
    - y_train : label value of dataset
    
    '''

    #find grid
    mygrid = GridSearchCV(model, param_grid = param_grid, cv = 5, n_jobs= 5, verbose = 2, scoring= 'neg_mean_squared_error')

    #fit grid
    mygrid.fit(X_train, y_train)
    
    #create result table
    params = mygrid.cv_results_['params']
    score = mygrid.cv_results_['mean_test_score']
    
    for i in range(len(params)) :
        params[i]['score'] = score[i]

    return pd.DataFrame(params).sort_values(by = 'score',ascending=False).set_index('score')

# %%
# rfr_result = search_grid(rfr, rfr_params, X_train, y_train)
# rfr_result
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
#            n_estimators
# score
# -0.031618           300
# -0.031626           400
# -0.031699           200
# -0.031869           100

# %%
lgb_result = search_grid(lgb, lgb_params, X_train, y_train)
lgb_result.head(10)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
#                max_depth  n_estimators
# score
# -1.290234e+10          6           400
# -1.298848e+10          6           300
# -1.314595e+10         10           400
# -1.316759e+10         10           300
# -1.319790e+10          6           200
# -1.324716e+10         10           200
# -1.333964e+10         -1           300
# -1.334627e+10         -1           400
# -1.340954e+10         -1           200
# -1.353192e+10         10           100

# %%
# sklearn.metrics.get_scorer_names()

# %%
models = [xgb, lgb, rfr]

# %%
def AveragingBlending(models, x, y, sub_x):
    for m in models : 
        m.fit(x.values, y)
    predictions = np.column_stack([
        m.predict(sub_x.values) for m in models
    ])
    return np.mean(predictions, axis=1)

# %%
result = AveragingBlending(models, X_train, y_train, X_test)

# %%
mean_squared_error(y_test, result)
# Out:
# 13406180884.935637

# %%
np.sqrt(13406180884)
# Out:
# 115785.06330265575

# %%
y = np.expm1(y)

# %%
get_score(rfr, train, y)
# Out:
# 127447.87089241878
