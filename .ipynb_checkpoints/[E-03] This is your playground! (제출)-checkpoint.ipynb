# %% [markdown]
# # 프로젝트 : This is your playground! Leaderboard를 정복해 주세요!
# ---

# %%
# import xgboost
# import lightgbm
# import missingno
# import sklearn

# print(xgboost.__version__)
# print(lightgbm.__version__)
# print(missingno.__version__)
# print(sklearn.__version__)

# %% [markdown]
# ## (1) 데이터 불러오기

# %%
import os
project_path = '../data/house_prices'
training_path = project_path + '/train.csv'
test_path = project_path + '/test.csv'

# %%
import pandas as pd
train = pd.read_csv(training_path)
test =  pd.read_csv(test_path)
print('train: ',train.shape)
print('test: ',test.shape)

print(set(train.columns)- set(test.columns))
# Out:
# train:  (15035, 21)
# test:  (6468, 20)
# {'price'}

# %% [markdown]
# ## (2) EDA

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15035 entries, 0 to 15034
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             15035 non-null  int64
#  1   date           15035 non-null  object
#  2   price          15035 non-null  float64
#  3   bedrooms       15035 non-null  int64
#  4   bathrooms      15035 non-null  float64
#  5   sqft_living    15035 non-null  int64
#  6   sqft_lot       15035 non-null  int64
#  7   floors         15035 non-null  float64
#  8   waterfront     15035 non-null  int64
#  9   view           15035 non-null  int64
#  10  condition      15035 non-null  int64
#  11  grade          15035 non-null  int64
#  12  sqft_above     15035 non-null  int64
#  13  sqft_basement  15035 non-null  int64
#  14  yr_built       15035 non-null  int64
#  15  yr_renovated   15035 non-null  int64
#  16  zipcode        15035 non-null  int64
#  17  lat            15035 non-null  float64
#  18  long           15035 non-null  float64
#  19  sqft_living15  15035 non-null  int64
#  20  sqft_lot15     15035 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 2.4+ MB

# %% [markdown]
# ### 2.1. 결측값 확인

# %%
train.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ## 2.2. 중복데이터 확인

# %%
train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 2.3. features 확인

# %% [markdown]
# ### 2.3.1. features 정의
# ---
# **Data fields**
#
# - `INT`
#     - ID : 집을 구분하는 번호 ⚠️
#     - bedrooms : 침실의 수
#     - sqft_living : 주거 공간의 평방 피트(면적)
#     - sqft_lot : 부지의 평방 피트(면적)
#     - waterfront : 집의 전방에 강이 흐르는지 유무 (a.k.a. 리버뷰)
#     - view : 집이 얼마나 좋아 보이는지의 정도
#     - condition : 집의 전반적인 상태
#     - grade : King County grading 시스템 기준으로 매긴 집의 등급
#     - sqft_above : 지하실을 제외한 평방 피트(면적)
#     - sqft_basement : 지하실의 평방 피트(면적)
#     - yr_built : 지어진 년도 #flag : date?
#     - yr_renovated : 집을 재건축한 년도
#     - zipcode : 우편번호
#     - sqft_living15 : 2015년 기준 주거 공간의 평방 피트(면적, 집을 재건축했다면, 변화가 있을 수 있음)
#     - sqft_lot15 : 2015년 기준 부지의 평방 피트(면적, 집을 재건축했다면, 변화가 있을 수 있음)
#
#
# - `FLOAT`
#     - bathrooms : 화장실의 수 ⚠️
#     - floors : 집의 층 수 ⚠️
#     - lat : 위도
#     - long : 경도
#
#
# - `OBJECT`
#     - date : 집을 구매한 날짜 ⚠️
#
#
# - `TARGET`
#     - price : 집의 가격(Target variable)
#
# `⚠️ : 주의깊게 살펴봐야할 feature`

# %% [markdown]
# ###  2.3.2. dtypes?

# %%
train.dtypes.value_counts()
# Out:
# int64      15
# float64     5
# object      1
# dtype: int64

# %%
col_int = [train.dtypes.index[i] for i in range(len(train.dtypes)) if train.dtypes[i] == 'int64']
col_float = [train.dtypes.index[i] for i in range(len(train.dtypes)) if train.dtypes[i] == 'float64' and train.dtypes.index[i] != 'price']
col_object = [train.dtypes.index[i] for i in range(len(train.dtypes)) if train.dtypes[i] == 'object']
target = 'price'

print('col_int : ', col_int)
print('col_float : ', col_float)
print('col_object : ', col_object)
# Out:
# col_int :  ['id', 'bedrooms', 'sqft_living', 'sqft_lot', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'sqft_living15', 'sqft_lot15']
# col_float :  ['bathrooms', 'floors', 'lat', 'long']
# col_object :  ['date']

# %% [markdown]
# ### 2.4. features correlations

# %% [markdown]
# High Corrlations :
#
# - sqft_living & sqft_above (0.88)
# - sqft_living & grade (0.76)
# - sqft_living & sqft_living15 (0.76)
# - sqft_living & bathrooms (0.75)
#
#
# \* *Grade(King County Grading System)*
# - 건축상태, 건축비용, 건축 디자인, 건축옵션 들을 고려한 체첨 시스템 </br>[source] https://info.kingcounty.gov/assessor/esales/Glossary.aspx?type=r

# %%
train.corr().style.background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_53200_row0_col0, #T_53200_row1_col1, #T_53200_row2_col2, #T_53200_row3_col3, #T_53200_row4_col4, #T_53200_row5_col5, #T_53200_row6_col6, #T_53200_row7_col7, #T_53200_row8_col8, #T_53200_row9_col9, #T_53200_row10_col10, #T_53200_row11_col11, #T_53200_row12_col12, #T_53200_row13_col13, #T_53200_row14_col14, #T_53200_row15_col15, #T_53200_row16_col16, #T_53200_row17_col17, #T_53200_row18_col18, #T_53200_row19_col19 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_53200_row0_col1, #T_53200_row6_col7, #T_53200_row8_col0, #T_53200_row9_col3 {
#   background-color: #fbfdce;
#   color: #000000;
# }
# #T_53200_row0_col2, #T_53200_row0_col12, #T_53200_row2_col19, #T_53200_row3_col16, #T_53200_row7_col19, #T_53200_row15_col8 {
#   background-color: #f1fab5;
#   color: #000000;
# }
# #T_53200_row0_col3, #T_53200_row5_col10, #T_53200_row6_col0, #T_53200_row19_col10 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# #T_53200_row0_col4, #T_53200_row1_col19, #T_53200_row10_col14, #T_53200_row18_col9 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_53200_row0_col5, #T_53200_row9_col11, #T_53200_row13_col12 {
#   background-color: #fafdc8;
#   color: #000000;
# }
# #T_53200_row0_col6, #T_53200_row5_col11, #T_53200_row12_col1, #T_53200_row18_col12 {
#   background-color: #b5e092;
#   color: #000000;
# }
# #T_53200_row0_col7 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_53200_row0_col8, #T_53200_row12_col0 {
#   background-color: #fcfed6;
#   color: #000000;
# }
# #T_53200_row0_col9, #T_53200_row3_col5, #T_53200_row8_col19, #T_53200_row11_col15, #T_53200_row13_col19 {
#   background-color: #e7f6ad;
#   color: #000000;
# }
# #T_53200_row0_col10, #T_53200_row8_col13, #T_53200_row14_col3 {
#   background-color: #dff3a8;
#   color: #000000;
# }
# #T_53200_row0_col11, #T_53200_row7_col14, #T_53200_row19_col9 {
#   background-color: #d5eea1;
#   color: #000000;
# }
# #T_53200_row0_col13, #T_53200_row1_col6, #T_53200_row8_col15 {
#   background-color: #9cd687;
#   color: #000000;
# }
# #T_53200_row0_col14, #T_53200_row11_col12, #T_53200_row16_col13 {
#   background-color: #f0f9b4;
#   color: #000000;
# }
# #T_53200_row0_col15, #T_53200_row2_col1, #T_53200_row2_col6, #T_53200_row19_col18 {
#   background-color: #b3e091;
#   color: #000000;
# }
# #T_53200_row0_col16, #T_53200_row8_col16, #T_53200_row14_col7, #T_53200_row19_col8 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_53200_row0_col17, #T_53200_row12_col18 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_53200_row0_col18 {
#   background-color: #ddf1a6;
#   color: #000000;
# }
# #T_53200_row0_col19, #T_53200_row6_col8 {
#   background-color: #f9fdc2;
#   color: #000000;
# }
# #T_53200_row1_col0, #T_53200_row9_col5, #T_53200_row9_col8, #T_53200_row14_col5, #T_53200_row14_col13 {
#   background-color: #f8fcbe;
#   color: #000000;
# }
# #T_53200_row1_col2, #T_53200_row3_col12 {
#   background-color: #9ad587;
#   color: #000000;
# }
# #T_53200_row1_col3, #T_53200_row18_col1 {
#   background-color: #49af61;
#   color: #f1f1f1;
# }
# #T_53200_row1_col4, #T_53200_row3_col11 {
#   background-color: #228343;
#   color: #f1f1f1;
# }
# #T_53200_row1_col5, #T_53200_row2_col14, #T_53200_row19_col6 {
#   background-color: #e6f5ac;
#   color: #000000;
# }
# #T_53200_row1_col7, #T_53200_row9_col17 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_53200_row1_col8, #T_53200_row6_col17 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_53200_row1_col9, #T_53200_row6_col1, #T_53200_row10_col8 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_53200_row1_col10 {
#   background-color: #2a8d49;
#   color: #f1f1f1;
# }
# #T_53200_row1_col11 {
#   background-color: #31974f;
#   color: #f1f1f1;
# }
# #T_53200_row1_col12 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_53200_row1_col13, #T_53200_row6_col2, #T_53200_row7_col1, #T_53200_row8_col9 {
#   background-color: #c7e89a;
#   color: #000000;
# }
# #T_53200_row1_col14, #T_53200_row2_col9, #T_53200_row11_col19, #T_53200_row12_col10 {
#   background-color: #c9e99c;
#   color: #000000;
# }
# #T_53200_row1_col15, #T_53200_row8_col3, #T_53200_row10_col12, #T_53200_row17_col10, #T_53200_row18_col8 {
#   background-color: #bee596;
#   color: #000000;
# }
# #T_53200_row1_col16, #T_53200_row12_col9 {
#   background-color: #a4d98a;
#   color: #000000;
# }
# #T_53200_row1_col17, #T_53200_row7_col15 {
#   background-color: #acdd8e;
#   color: #000000;
# }
# #T_53200_row1_col18 {
#   background-color: #359c53;
#   color: #f1f1f1;
# }
# #T_53200_row2_col0 {
#   background-color: #f8fdc1;
#   color: #000000;
# }
# #T_53200_row2_col3, #T_53200_row3_col6 {
#   background-color: #47ae60;
#   color: #f1f1f1;
# }
# #T_53200_row2_col4, #T_53200_row3_col18 {
#   background-color: #379e54;
#   color: #f1f1f1;
# }
# #T_53200_row2_col5, #T_53200_row4_col7, #T_53200_row5_col1, #T_53200_row5_col8, #T_53200_row9_col18, #T_53200_row12_col19 {
#   background-color: #f3fab6;
#   color: #000000;
# }
# #T_53200_row2_col7 {
#   background-color: #fdfeda;
#   color: #000000;
# }
# #T_53200_row2_col8 {
#   background-color: #f2fab5;
#   color: #000000;
# }
# #T_53200_row2_col10 {
#   background-color: #83cb7d;
#   color: #000000;
# }
# #T_53200_row2_col11 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_53200_row2_col12, #T_53200_row2_col17 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_53200_row2_col13 {
#   background-color: #a9db8c;
#   color: #000000;
# }
# #T_53200_row2_col15, #T_53200_row7_col4, #T_53200_row14_col12, #T_53200_row16_col9, #T_53200_row17_col2 {
#   background-color: #d7efa2;
#   color: #000000;
# }
# #T_53200_row2_col16, #T_53200_row9_col14, #T_53200_row14_col19 {
#   background-color: #f7fcb9;
#   color: #000000;
# }
# #T_53200_row2_col18 {
#   background-color: #69bf72;
#   color: #000000;
# }
# #T_53200_row3_col0, #T_53200_row6_col14, #T_53200_row8_col5, #T_53200_row16_col3, #T_53200_row17_col9, #T_53200_row18_col14, #T_53200_row18_col15 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_53200_row3_col1, #T_53200_row6_col10 {
#   background-color: #62bb6e;
#   color: #f1f1f1;
# }
# #T_53200_row3_col2, #T_53200_row13_col6 {
#   background-color: #4eb163;
#   color: #f1f1f1;
# }
# #T_53200_row3_col4, #T_53200_row11_col18 {
#   background-color: #167a3f;
#   color: #f1f1f1;
# }
# #T_53200_row3_col7, #T_53200_row12_col7, #T_53200_row17_col0 {
#   background-color: #f8fcc0;
#   color: #000000;
# }
# #T_53200_row3_col8, #T_53200_row5_col3, #T_53200_row16_col6, #T_53200_row18_col5, #T_53200_row19_col3 {
#   background-color: #dbf1a4;
#   color: #000000;
# }
# #T_53200_row3_col9, #T_53200_row5_col14, #T_53200_row6_col16, #T_53200_row18_col16, #T_53200_row19_col14 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_53200_row3_col10, #T_53200_row4_col1 {
#   background-color: #2b8e4a;
#   color: #f1f1f1;
# }
# #T_53200_row3_col13 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_53200_row3_col14, #T_53200_row4_col14, #T_53200_row4_col15, #T_53200_row7_col3, #T_53200_row7_col6, #T_53200_row7_col10, #T_53200_row8_col6, #T_53200_row10_col16, #T_53200_row10_col19, #T_53200_row15_col14 {
#   background-color: #ddf2a6;
#   color: #000000;
# }
# #T_53200_row3_col15, #T_53200_row4_col9, #T_53200_row11_col8, #T_53200_row12_col16, #T_53200_row14_col11 {
#   background-color: #def2a7;
#   color: #000000;
# }
# #T_53200_row3_col17, #T_53200_row5_col17, #T_53200_row18_col13 {
#   background-color: #75c578;
#   color: #000000;
# }
# #T_53200_row3_col19, #T_53200_row11_col14, #T_53200_row16_col11, #T_53200_row16_col14 {
#   background-color: #e4f4ab;
#   color: #000000;
# }
# #T_53200_row4_col0, #T_53200_row12_col5, #T_53200_row16_col2, #T_53200_row19_col1 {
#   background-color: #f6fcb8;
#   color: #000000;
# }
# #T_53200_row4_col2 {
#   background-color: #3aa257;
#   color: #f1f1f1;
# }
# #T_53200_row4_col3, #T_53200_row4_col10, #T_53200_row11_col10, #T_53200_row18_col4 {
#   background-color: #15793e;
#   color: #f1f1f1;
# }
# #T_53200_row4_col5, #T_53200_row7_col11, #T_53200_row12_col17 {
#   background-color: #d2eda0;
#   color: #000000;
# }
# #T_53200_row4_col6 {
#   background-color: #7ac77a;
#   color: #000000;
# }
# #T_53200_row4_col8, #T_53200_row5_col18 {
#   background-color: #bde496;
#   color: #000000;
# }
# #T_53200_row4_col11 {
#   background-color: #005f34;
#   color: #f1f1f1;
# }
# #T_53200_row4_col12 {
#   background-color: #64bc6f;
#   color: #f1

# %% [markdown]
# ### 2.5. target column

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
price = train[target]
fig = plt.figure(figsize = (6,8))
ax = fig.add_subplot(2,1,1)
sns.boxplot(y=price)

ax1 = fig.add_subplot(2,1,2)
sns.kdeplot(x=price)

plt.show()

# %%
# remove outliers
train[train['price'] < 6000000]
train = train[train['price'] < 6000000]

# %% [markdown]
# ### 2.6. int64 features
# ---

# %%
def graph_hist_scatter(dataset, feature, target):
    fig = plt.figure(figsize = (12,4))

    ax = fig.add_subplot(1,2,1)
    sns.histplot(data=dataset, x=feature)
    plt.title(f'{feature} hist')
    plt.xlabel('')

    ax = fig.add_subplot(1,2,2)
    sns.regplot(data=dataset, x=feature, y=target)
    plt.title(f'{feature} vs {target}')
    plt.xlabel('')
    plt.show()

# %%
def graph_count_scatter(dataset, feature, target):
    fig = plt.figure(figsize = (12,4))

    ax = fig.add_subplot(1,2,1)
    sns.countplot(data=dataset, x=feature)
    plt.title(f'{feature} count')
    plt.xlabel('')

    ax = fig.add_subplot(1,2,2)
    sns.regplot(data=dataset, x=feature, y=target)
    plt.title(f'{feature} vs {target}')
    plt.xlabel('')
    plt.show()

# %%
def graph_count_box(dataset, feature, target):
    fig = plt.figure(figsize = (12,4))

    ax = fig.add_subplot(1,2,1)
    sns.countplot(data=dataset, x=feature)
    plt.title(f'{feature} count')
    plt.xlabel('')

    ax = fig.add_subplot(1,2,2)
    sns.boxplot(data=dataset, x=feature, y=target)
    plt.title(f'{feature} vs {target}')
    plt.xlabel('')
    plt.show()

# %%
def graph_hist_box(dataset, feature, target):
    fig = plt.figure(figsize = (12,4))

    ax = fig.add_subplot(1,2,1)
    sns.histplot(data=dataset, x=feature)
    plt.title(f'{feature} hist')

    ax = fig.add_subplot(1,2,2)
    sns.boxplot(data=dataset, x=feature, y=target)
    plt.title(f'{feature} vs {target}')
    plt.show()

# %% [markdown]
# ### 2.6.1. ID

# %% [markdown]
# ID는 각 데이터의 고유번호로 큰 의미가 없습니다. 모델 분석시에는 제외하도록 하겠습니다.

# %% [markdown]
# ### 2.6.2. Bedrooms

# %%
graph_count_scatter(train, 'bedrooms', 'price')

# %% [markdown]
# ### 2.6.3. sqft_living vs sqft_above vs sqft_basement

# %%
# sqft_living - sqft_above = sqft_basement
train[['sqft_living15','sqft_living','sqft_above','sqft_basement','sqft_lot','sqft_lot15']]
# Out:
#        sqft_living15  sqft_living  sqft_above  sqft_basement  sqft_lot  \
# 0               1340         1180        1180              0      5650
# 1               2720          770         770              0     10000
# 2               1800         1680        1680              0      8080
# 3               2238         1715        1715              0      6819
# 4               1650         1060        1060              0      9711
# ...              ...          ...         ...            ...       ...
# 15030           2520         2520        2520              0      6023
# 15031           2050         3510        2600            910      7200
# 15032           1530         1530        1530              0      1131
# 15033           1830         2310        2310              0      5813
# 15034           1020         1020        1020              0      1076
#
#        sqft_lot15
# 0            5650
# 1            8062
# 2            7503
# 3            6819
# 4            9711
# ...           ...
# 15030        6023
# 15031        6200
# 15032        1509
# 15033        7200
# 15034        1357
#
# [15032 rows x 6 columns]

# %%
sqft =['sqft_living15','sqft_living','sqft_above','sqft_basement','sqft_lot','sqft_lot15']

fig = plt.figure(figsize = (10,8))
for i, col in enumerate(sqft) :
    ax = fig.add_subplot(3,2,i+1)
    sns.kdeplot(data=train,x=col)
    plt.xlabel('')
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
from scipy.stats import skew

# %% [markdown]
# 모든 feature들의 왜도 값이 1 이상입니다.
#
# np.log1p 를 이용해서 정규화 작업이 필요합니다.

# %%
for i in sqft :
    print(f'Skewness of {i} : {skew(train[i])}')
# Out:
# Skewness of sqft_living15 : 1.1245791992721614
# Skewness of sqft_living : 1.3662992910648408
# Skewness of sqft_above : 1.3586428334669851
# Skewness of sqft_basement : 1.5383473836638848
# Skewness of sqft_lot : 13.348714594309834
# Skewness of sqft_lot15 : 10.027990160682432

# %%
fig = plt.figure(figsize = (10,8))
for i, col in enumerate(sqft) :
    ax = fig.add_subplot(3,2,i+1)
    sns.regplot(data=train,x=col, y='price')
    plt.xlabel('')
    plt.title(f"{col} vs. price")

plt.tight_layout()
plt.show()

# %%
#sqft_living and sqft_above remove from model

train[sqft].corr().style.background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_bac70_row0_col0, #T_bac70_row1_col1, #T_bac70_row2_col2, #T_bac70_row3_col3, #T_bac70_row4_col4, #T_bac70_row5_col5 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_bac70_row0_col1 {
#   background-color: #2d914b;
#   color: #f1f1f1;
# }
# #T_bac70_row0_col2 {
#   background-color: #228343;
#   color: #f1f1f1;
# }
# #T_bac70_row0_col3 {
#   background-color: #dcf1a5;
#   color: #000000;
# }
# #T_bac70_row0_col4 {
#   background-color: #f6fcb8;
#   color: #000000;
# }
# #T_bac70_row0_col5 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_bac70_row1_col0 {
#   background-color: #2a8d49;
#   color: #f1f1f1;
# }
# #T_bac70_row1_col2 {
#   background-color: #006536;
#   color: #f1f1f1;
# }
# #T_bac70_row1_col3 {
#   background-color: #89ce80;
#   color: #000000;
# }
# #T_bac70_row1_col4 {
#   background-color: #eef9b3;
#   color: #000000;
# }
# #T_bac70_row1_col5 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_bac70_row2_col0 {
#   background-color: #30954f;
#   color: #f1f1f1;
# }
# #T_bac70_row2_col1 {
#   background-color: #076d39;
#   color: #f1f1f1;
# }
# #T_bac70_row2_col3, #T_bac70_row3_col2, #T_bac70_row3_col4, #T_bac70_row3_col5, #T_bac70_row4_col0, #T_bac70_row4_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_bac70_row2_col4 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_bac70_row2_col5 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_bac70_row3_col0 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# #T_bac70_row3_col1 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_bac70_row4_col2 {
#   background-color: #def2a7;
#   color: #000000;
# }
# #T_bac70_row4_col3 {
#   background-color: #fbfdce;
#   color: #000000;
# }
# #T_bac70_row4_col5, #T_bac70_row5_col4 {
#   background-color: #298c48;
#   color: #f1f1f1;
# }
# #T_bac70_row5_col0 {
#   background-color: #fcfed7;
#   color: #000000;
# }
# #T_bac70_row5_col1 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_bac70_row5_col2 {
#   background-color: #ddf1a6;
#   color: #000000;
# }
# #T_bac70_row5_col3 {
#   background-color: #fafdcc;
#   color: #000000;
# }
# </style>
# <table id="T_bac70">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bac70_level0_col0" class="col_heading level0 col0" >sqft_living15</th>
#       <th id="T_bac70_level0_col1" class="col_heading level0 col1" >sqft_living</th>
#       <th id="T_bac70_level0_col2" class="col_heading level0 col2" >sqft_above</th>
#       <th id="T_bac70_level0_col3" class="col_heading level0 col3" >sqft_basement</th>
#       <th id="T_bac70_level0_col4" class="col_heading level0 col4" >sqft_lot</th>
#       <th id="T_bac70_level0_col5" class="col_heading level0 col5" >sqft_lot15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bac70_level0_row0" class="row_heading level0 row0" >sqft_living15</th>
#       <td id="T_bac70_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_bac70_row0_col1" class="data row0 col1" >0.761994</td>
#       <td id="T_bac70_row0_col2" class="data row0 col2" >0.738230</td>
#       <td id="T_bac70_row0_col3" class="data row0 col3" >0.196434</td>
#       <td id="T_bac70_row0_col4" class="data row0 col4" >0.147466</td>
#       <td id="T_bac70_row0_col5" class="data row0 col5" >0.183465</td>
#     </tr>
#     <tr>
#       <th id="T_bac70_level0_row1" class="row_heading level0 row1" >sqft_living</th>
#       <td id="T_bac70_row1_col0" class="data row1 col0" >0.761994</td>
#       <td id="T_bac70_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_bac70_row1_col2" class="data row1 col2" >0.877210</td>
#       <td id="T_bac70_row1_col3" class="data row1 col3" >0.430044</td>
#       <td id="T_bac70_row1_col4" class="data row1 col4" >0.177344</td>
#       <td id="T_bac70_row1_col5" class="data row1 col5" >0.185046</td>
#     </tr>
#     <tr>
#       <th id="T_bac70_level0_row2" class="row_heading level0 row2" >sqft_above</th>
#       <td id="T_bac70_row2_col0" class="data row2 col0" >0.738230</td>
#       <td id="T_bac70_row2_col1" class="data row2 col1" >0.877210</td>
#       <td id="T_bac70_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_bac70_row2_col3" class="data row2 col3" >-0.056206</td>
#       <td id="T_bac70_row2_col4" class="data row2 col4" >0.186808</td>
#       <td id="T_bac70_row2_col5" class="data row2 col5" >0.194715</td>
#     </tr>
#     <tr>
#       <th id="T_bac70_level0_row3" class="row_heading level0 row3" >sqft_basement</th>
#       <td id="T_bac70_row3_col0" class="data row3 col0" >0.196434</td>
#       <td id="T_bac70_row3_col1" class="data row3 col1" >0.430044</td>
#       <td id="T_bac70_row3_col2" class="data row3 col2" >-0.056206</td>
#       <td id="T_bac70_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_bac70_row3_col4" class="data row3 col4" >0.017521</td>
#       <td id="T_bac70_row3_col5" class="data row3 col5" >0.018668</td>
#     </tr>
#     <tr>
#       <th id="T_bac70_level0_row4" class="row_heading level0 row4" >sqft_lot</th>
#       <td id="T_bac70_row4_col0" class="data row4 col0" >0.147466</td>
#       <td id="T_bac70_row4_col1" class="data row4 col1" >0.177344</td>
#       <td id="T_bac70_row4_col2" class="data row4 col2" >0.186808</td>
#       <td id="T_bac70_row4_col3" class="data row4 col3" >0.017521</td>
#       <td id="T_bac70_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_bac70_row4_col5" class="data row4 col5" >0.728463</td>
#     </tr>
#     <tr>
#       <th id="T_bac70_level0_row5" class="row_heading level0 row5" >sqft_lot15</th>
#       <td id="T_bac70_row5_col0" class="data row5 col0" >0.183465</td>
#       <td id="T_bac70_row5_col1" class="data row5 col1" >0.185046</td>
#       <td id="T_bac70_row5_col2" class="data row5 col2" >0.194715</td>
#       <td id="T_bac70_row5_col3" class="data row5 col3" >0.018668</td>
#       <td id="T_bac70_row5_col4" class="data row5 col4" >0.728463</td>
#       <td id="T_bac70_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 2.6.4. waterfront

# %% [markdown]
# 주변에 물이 많은 것 같습니다.
#
# 가격 예측하는데는 이 도시에서는 큰 도움을 받기는 어렵겠네요.

# %%
fig = plt.figure(figsize = (6,3))
sns.histplot(train['waterfront'])
plt.title('waterfront')
plt.show()

# %%
graph_count_box(train, 'waterfront', 'price')

# %% [markdown]
# ### 2.6.5. view

# %%
fig = plt.figure(figsize = (6,3))
sns.histplot(train['view'])
plt.title('view')
plt.show()

# %%
graph_count_box(train, 'view', 'price')

# %% [markdown]
# ### 2.6.6. condition

# %%
graph_count_box(train, 'condition', 'price')

# %% [markdown]
# ### 2.6.7. grade

# %%
graph_count_box(train, 'grade', 'price')

# %% [markdown]
# ### 2.6.8. yr_built & yr_renovated

# %%
graph_hist_scatter(train,'yr_built','price')

# %%
graph_hist_scatter(train,'yr_renovated','price')

# %% [markdown]
# ### 2.6.9. zipcode

# %%
sns.scatterplot(data=train, y='price', x='zipcode', hue= 'grade', palette = 'colorblind')
plt.show()

# %% [markdown]
# ### 2.7. float features

# %% [markdown]
# ---

# %% [markdown]
# ### 2.7.1 bathrooms

# %%
train['bathrooms'].value_counts().sort_index()
# Out:
# 0.00       4
# 0.50       3
# 0.75      45
# 1.00    2675
# 1.25       5
# 1.50    1009
# 1.75    2112
# 2.00    1357
# 2.25    1433
# 2.50    3748
# 2.75     843
# 3.00     493
# 3.25     410
# 3.50     510
# 3.75     108
# 4.00     100
# 4.25      57
# 4.50      63
# 4.75      16
# 5.00      14
# 5.25      11
# 5.50       7
# 5.75       3
# 6.00       2
# 6.25       1
# 6.75       1
# 7.50       1
# 8.00       1
# Name: bathrooms, dtype: int64

# %%
graph_hist_scatter(train, 'bathrooms','price')

# %% [markdown]
# ### 2.7.2. floor

# %%
graph_count_box(train, 'floors','price')

# %% [markdown]
# ### 2.7.3. latitude and longitude

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
train['pricerange'] = pd.qcut(x = train['price'], q =5, labels=[1,2,3,4,5] )

# %%
sns.scatterplot(data= train,x='long',y ='lat', hue='pricerange')
plt.show()

# %% [markdown]
# 위도 경고 좌표를 구글 맵 찍어봤을 때 미국 워싱턴 주를 가르키는 것 같습니다.
#
# 주요 도시로 Seattle과 Bellavue가 보입니다.
#
# 주요 도시와의 거리도 가격을 설명해주는 feature로 사용하면 좋을 것 같습니다.
#
# 거리를 측정해주는 방법으로는 harvesine 함수를 사용하겠습니다.
#
# 식은 다음 이미지와 같습니다.
#
# 이를 이용해서 주요 도시 Seattle과 Bellavue와의 거리를 측정해서 새로운 feature를 만들어보겠습니다.
#
# ![image.png](attachment:image.png)
#
# https://medium.com/@krexvelasco/transforming-categorical-information-into-usable-measures-in-a-machine-learning-model-e2910bbb3fc7

# %%
# !pip install haversine

# %%
from haversine import haversine, Unit

# %%
# dbscan
# number of classes given cluster

# %%
seattle = [46.6092, -122.3363]
bellevue = [47.61555, -122.20392]

# %%
haversine(seattle, bellevue,unit=Unit.MILES)
# Out:
# 69.8102115661099

# %%
#train
train['coordinates'] = list(zip(train['lat'],train['long']))
train['seattle_dist'] = train['coordinates'].apply(lambda x: haversine(x,seattle,unit =Unit.MILES))
train['bellevue_dist'] = train['coordinates'].apply(lambda x: haversine(x,bellevue,unit =Unit.MILES))

#test
test['coordinates'] = list(zip(test['lat'],test['long']))
test['seattle_dist'] = test['coordinates'].apply(lambda x: haversine(x,seattle,unit =Unit.MILES))
test['bellevue_dist'] = test['coordinates'].apply(lambda x: haversine(x,bellevue,unit =Unit.MILES))

# %%
graph_hist_scatter(train, 'seattle_dist','price')

# %%
graph_hist_scatter(train, 'bellevue_dist','price')

# %%
train[['price','seattle_dist','bellevue_dist','lat','long']].corr().style.background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_32d57_row0_col0, #T_32d57_row1_col1, #T_32d57_row1_col3, #T_32d57_row2_col2, #T_32d57_row3_col1, #T_32d57_row3_col3, #T_32d57_row4_col4 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_32d57_row0_col1 {
#   background-color: #51b365;
#   color: #f1f1f1;
# }
# #T_32d57_row0_col2 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_32d57_row0_col3 {
#   background-color: #4eb163;
#   color: #f1f1f1;
# }
# #T_32d57_row0_col4 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_32d57_row1_col0, #T_32d57_row3_col0 {
#   background-color: #72c376;
#   color: #000000;
# }
# #T_32d57_row1_col2 {
#   background-color: #feffde;
#   color: #000000;
# }
# #T_32d57_row1_col4 {
#   background-color: #fafdc8;
#   color: #000000;
# }
# #T_32d57_row2_col0, #T_32d57_row2_col1, #T_32d57_row2_col3, #T_32d57_row3_col2, #T_32d57_row3_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_32d57_row2_col4, #T_32d57_row4_col3 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_32d57_row4_col0 {
#   background-color: #c3e698;
#   color: #000000;
# }
# #T_32d57_row4_col1 {
#   background-color: #acdd8e;
#   color: #000000;
# }
# #T_32d57_row4_col2 {
#   background-color: #5fba6c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_32d57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32d57_level0_col0" class="col_heading level0 col0" >price</th>
#       <th id="T_32d57_level0_col1" class="col_heading level0 col1" >seattle_dist</th>
#       <th id="T_32d57_level0_col2" class="col_heading level0 col2" >bellevue_dist</th>
#       <th id="T_32d57_level0_col3" class="col_heading level0 col3" >lat</th>
#       <th id="T_32d57_level0_col4" class="col_heading level0 col4" >long</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32d57_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_32d57_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_32d57_row0_col1" class="data row0 col1" >0.310942</td>
#       <td id="T_32d57_row0_col2" class="data row0 col2" >-0.417332</td>
#       <td id="T_32d57_row0_col3" class="data row0 col3" >0.309819</td>
#       <td id="T_32d57_row0_col4" class="data row0 col4" >0.025594</td>
#     </tr>
#     <tr>
#       <th id="T_32d57_level0_row1" class="row_heading level0 row1" >seattle_dist</th>
#       <td id="T_32d57_row1_col0" class="data row1 col0" >0.310942</td>
#       <td id="T_32d57_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_32d57_row1_col2" class="data row1 col2" >-0.665851</td>
#       <td id="T_32d57_row1_col3" class="data row1 col3" >0.994206</td>
#       <td id="T_32d57_row1_col4" class="data row1 col4" >-0.039761</td>
#     </tr>
#     <tr>
#       <th id="T_32d57_level0_row2" class="row_heading level0 row2" >bellevue_dist</th>
#       <td id="T_32d57_row2_col0" class="data row2 col0" >-0.417332</td>
#       <td id="T_32d57_row2_col1" class="data row2 col1" >-0.665851</td>
#       <td id="T_32d57_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_32d57_row2_col3" class="data row2 col3" >-0.703235</td>
#       <td id="T_32d57_row2_col4" class="data row2 col4" >0.245347</td>
#     </tr>
#     <tr>
#       <th id="T_32d57_level0_row3" class="row_heading level0 row3" >lat</th>
#       <td id="T_32d57_row3_col0" class="data row3 col0" >0.309819</td>
#       <td id="T_32d57_row3_col1" class="data row3 col1" >0.994206</td>
#       <td id="T_32d57_row3_col2" class="data row3 col2" >-0.703235</td>
#       <td id="T_32d57_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_32d57_row3_col4" class="data row3 col4" >-0.133435</td>
#     </tr>
#     <tr>
#       <th id="T_32d57_level0_row4" class="row_heading level0 row4" >long</th>
#       <td id="T_32d57_row4_col0" class="data row4 col0" >0.025594</td>
#       <td id="T_32d57_row4_col1" class="data row4 col1" >-0.039761</td>
#       <td id="T_32d57_row4_col2" class="data row4 col2" >0.245347</td>
#       <td id="T_32d57_row4_col3" class="data row4 col3" >-0.133435</td>
#       <td id="T_32d57_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
ballard = (47.682061, -122.393882)
lakecity =(47.723538, -122.286637)
wedgewood = (47.689600, -122.295537)
wu = (47.656250, -122.311010)
wf =(47.656627, -122.339032)
lp = (47.652656, -122.397650)
sn =(47.614038, -122.347546)
ch =(47.621543, -122.317746)
wp =(47.626178, -122.288273)
square = (47.600188, -122.332234)
norhtadmiral = (47.576393, -122.390178)
roxhill = (47.522859, -122.374381)
georgetown =(47.550410, -122.328636)
kubota = (47.516414, -122.272688)
colombia = (47.555963, -122.275979)
sodo =(47.585051, -122.330610)
cdis =(47.605163, -122.297362)
madrona =(47.616688, -122.293445)
walling =(47.668264, -122.329730)

# %%
points =[ballard, lakecity, wedgewood, wu, wf, lp, sn, ch, wp, square, norhtadmiral, roxhill, georgetown, kubota, colombia, sodo, cdis, madrona, walling]
points[8]
# Out:
# (47.626178, -122.288273)

# %%
len(points)
# Out:
# 19

# %%
from sklearn.cluster import KMeans
kmean = KMeans(n_clusters = 19, init = points, n_init=1, random_state=2022)
clusterdata = train.loc[:,['lat', 'long']].values
kmean.fit(clusterdata)
kmean.labels_
train['region'] = kmean.labels_
clusterdata_test = test.loc[:,['lat', 'long']].values
kmean.fit_transform(clusterdata_test)
test['region'] =  kmean.labels_

# %%
sns.scatterplot(data= train,x='long',y ='lat', hue='region')
plt.show()

# %%
sns.scatterplot(data= test,x='long',y ='lat', hue='region')
plt.show()

# %%
graph_count_box(train, 'region','price')

# %%
train['region'].value_counts()
# Out:
# 10    1084
# 16    1081
# 18    1037
# 8     1024
# 17    1010
# 11     951
# 4      949
# 15     921
# 0      849
# 6      842
# 13     835
# 7      801
# 5      729
# 3      680
# 12     665
# 2      664
# 1      473
# 14     423
# 9       14
# Name: region, dtype: int64

# %%
mapping = {0 : (47.682061, -122.393882),
1 : (47.723538, -122.286637),
2 : (47.689600, -122.295537),
3 : (47.656250, -122.311010),
4 : (47.656627, -122.339032),
5 : (47.652656, -122.397650),
6 : (47.614038, -122.347546),
7 : (47.621543, -122.317746),
8 : (47.626178, -122.288273),
9 : (47.600188, -122.332234),
10 : (47.576393, -122.390178),
11 : (47.522859, -122.374381),
12 : (47.550410, -122.328636),
13 : (47.516414, -122.272688),
14 : (47.555963, -122.275979),
15 : (47.585051, -122.330610),
16 : (47.605163, -122.297362),
17 : (47.616688, -122.293445),
18 : (47.668264, -122.329730)}

for data in [train, test] :
    data['centroid'] = data['region'].apply(lambda x : mapping[x])
    data['centroid_dist'] = data.apply(lambda x : haversine(x['centroid'],x['coordinates'],unit =Unit.MILES),axis=1)
    data['centroid_dist']

# %%
sns.scatterplot(data =train , x='centroid_dist', y='price', hue='pricerange')
plt.show()

# %% [markdown]
# ### 2.7. date feature

# %% [markdown]
# date feature는 현재 object 자료형입니다. 회귀 모델에 사용하기 위해서 숫자로 바꿔주겠습니다.

# %%
train['date'].describe()
# Out:
# count               15032
# unique                365
# top       20140623T000000
# freq                  101
# Name: date, dtype: object

# %%
#train
train['date'] = train['date'].apply(lambda x : x[:8]).astype(int)

#test
test['date'] = test['date'].apply(lambda x : x[:8]).astype(int)

# %%
train['date'].describe()
# Out:
# count    1.503200e+04
# mean     2.014387e+07
# std      4.425365e+03
# min      2.014050e+07
# 25%      2.014072e+07
# 50%      2.014102e+07
# 75%      2.015021e+07
# max      2.015051e+07
# Name: date, dtype: float64

# %% [markdown]
# ## (3) Feature Engineering and Feature Selection and Feature Scaling

# %% [markdown]
# ### 3.1. Feature Engineering

# %%
#train
train['floor_area_ratio'] = train['sqft_living'] / train['sqft_lot']
train['rooms'] = train['bedrooms'] + train['bathrooms']
train['grade_condition'] = train['grade'] * train['condition']
train['sqft_total_size'] = train['sqft_above'] + train['sqft_basement']

#test
test['floor_area_ratio'] = test['sqft_living'] / test['sqft_lot']
test['rooms'] = test['bedrooms'] + test['bathrooms']
test['grade_condition'] = test['grade'] * test['condition']
test['sqft_total_size'] = test['sqft_above'] + test['sqft_basement']

# source : https://www.kaggle.com/code/chocozzz/house-price-prediction-eda-updated-2019-03-12

# %%
for df in [train, test]:
    df['yr_renovated'] = df['yr_renovated'].apply(lambda x: np.nan if x == 0 else x)
    df['yr_renovated'] = df['yr_renovated'].fillna(df['yr_built'])

# %%
#one-hot encoding
train = pd.get_dummies(train, columns = ['region'])
test = pd.get_dummies(test, columns = ['region'])

# %% [markdown]
# ### 3.2. Feature Selection

# %%
train.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'pricerange',
#        'coordinates', 'seattle_dist', 'bellevue_dist', 'centroid',
#        'centroid_dist', 'floor_area_ratio', 'rooms', 'grade_condition',
#        'sqft_total_size', 'region_0', 'region_1', 'region_2', 'region_3',
#        'region_4', 'region_5', 'region_6', 'region_7', 'region_8', 'region_9',
#        'region_10', 'region_11', 'region_12', 'region_13', 'region_14',
#        'region_15', 'region_16', 'region_17', 'region_18'],
#       dtype='object')

# %%
set(train.columns) - set(test.columns)
# Out:
# {'price', 'pricerange'}

# %%
removing_feature = ['id', 'coordinates', 'centroid','price','pricerange'] #'lat','long','sqft_living15','sqft_above',

removing_feature.extend(['sqft_living', 'region_9','region_18', 'region_1', 'region_11', 'region_13', 'region_17', 'region_14'])

# %%
selected_feature = list(set(train.columns) - set(removing_feature))

# %%
import numpy as np

for i in sqft :
    train[i] = train[i].apply(lambda x : np.log1p(x))
    test[i] = test[i].apply(lambda x : np.log1p(x))

# %%
X_train = train[selected_feature].values
y_train = train['price'].apply(lambda x : np.log1p(x))
X_test = test[selected_feature].values

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (15032, 37)
# (15032,)
# (6468, 37)

# %% [markdown]
# ### 3.3. Feature Scaling

# %%
# from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# %%
scaler = RobustScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)

X_test = scaler.transform(X_test)

# %% [markdown]
# ## (4) Train Validation Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_t, X_v, y_t, y_v = train_test_split(X_train, y_train, test_size=0.2, random_state=2022)

# %% [markdown]
# ## (5) Model Baseline

# %%
# Import Model
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

# Metric
from sklearn.metrics import mean_squared_error

# %%
model = LGBMRegressor(random_state=2022)

def get_score_prediction(model, x,y, test, true) :
    model.fit(x,y)
    pred = model.predict(test)
    print('RMSE is :', mean_squared_error(np.expm1(true), np.expm1(pred)) ** 0.5)
    return np.expm1(pred)

get_score_prediction(model, X_t, y_t, X_v, y_v)
# Out:
# RMSE is : 107117.92927203917
# array([831983.34844467, 514027.38774424, 184030.16612853, ...,
#        668242.56447993, 520834.69906041, 211582.95445378])

# %%
model2 = XGBRegressor(random_state=2022)
get_score_prediction(model2, X_t, y_t, X_v, y_v)
# Out:
# RMSE is : 116642.8856870415
# array([805759.4 , 417380.22, 181328.72, ..., 666924.6 , 505228.3 ,
#        233927.78], dtype=float32)

# %%
model3 = RandomForestRegressor(random_state=2022)
get_score_prediction(model3, X_t, y_t, X_v, y_v)
# Out:
# RMSE is : 131538.62477904127
# array([891205.90972807, 476809.33467513, 168676.90347158, ...,
#        623328.17465556, 489460.52974688, 232132.97384675])

# %%
model4 = RidgeCV(cv=10)
get_score_prediction(model4, X_t, y_t, X_v, y_v)
# Out:
# RMSE is : 141266.6342165597
# array([935244.08285722, 482171.03440414, 199765.30399702, ...,
#        755282.26410866, 512644.65028528, 249114.54857753])

# %%
model5 = LinearRegression()
get_score_prediction(model5, X_t, y_t, X_v, y_v)
# Out:
# RMSE is : 141212.3557614117
# array([934511.09280135, 481918.87370625, 199672.18937004, ...,
#        754268.10468747, 512663.55129585, 249099.92218735])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()

vif["Features"] = train[selected_feature].columns
vif["VIF Values"] = [variance_inflation_factor(
    train[selected_feature].values, i) for i in range(train[selected_feature].shape[1])]

vif.sort_values(by='VIF Values',ascending=False)
# Out:
# /Users/seungyonglee/miniconda3/lib/python3.9/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/seungyonglee/miniconda3/lib/python3.9/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/seungyonglee/miniconda3/lib/python3.9/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#             Features    VIF Values
# 14         bathrooms           inf
# 23          bedrooms           inf
# 9              rooms           inf
# 34               lat  5.963694e+07
# 36              date  1.745371e+07
# 12              long  1.646484e+07
# 32           zipcode  1.147103e+07
# 8       yr_renovated  3.129439e+04
# 19          yr_built  3.073728e+04
# 15      seattle_dist  2.486438e+04
# 7         sqft_above  3.649082e+03
# 24     sqft_living15  1.561643e+03
# 11             grade  1.434801e+03
# 28   grade_condition  1.366911e+03
# 0          condition  1.275854e+03
# 4           sqft_lot  8.736169e+02
# 27        sqft_lot15  8.187889e+02
# 22     centroid_dist  1.156017e+02
# 5      bellevue_dist  8.504861e+01
# 21   sqft_total_size  7.041376e+01
# 31            floors  2.635923e+01
# 3   floor_area_ratio  1.163235e+01
# 30     sqft_basement  5.567604e+00
# 33         region_10  4.253603e+00
# 17          region_5  3.994535e+00
# 29          region_4  3.883759e+00
# 16          region_0  3.337998e+00
# 25          region_6  2.882471e+00
# 1          region_12  2.843946e+00
# 10          region_3  2.491530e+00
# 13          region_7  2.342299e+00
# 6          region_15  1.984867e+00
# 35         region_16  1.698960e+00
# 2           region_8  1.674710e+00
# 26              view  1.558452e+00
# 20          region_2  1.354317e+00
# 18        waterfront  1.214482e+00

# %% [markdown]
# 보통의 경우 10 이상이면 다중공선성이 존재한다고 말하는데, 위의 식에서는 waterfront, view, sqft_lot15, is_renovated 4가지 변수를 제외한 모든 변수들에서 다중공선성이 존재하는 문제점이 있습니다.
#
# 이를 해결하기 위한 방안으로는
#
# - 다중공선성에 robust한 트리모델을 사용하는 방법
# - 변수제거 및 FE, 변환등을 통한 대체
# - 관측값을 늘려 표본의 크기를 증가
#
# 하지만 마지막 3의 방안은 실현이 불가능하고 선형회귀를 사용할거면 2를 최대한 활용하고, 그렇지 않을 경우에는 1번 방안을 사용하면 됩니다.
#
# https://www.kaggle.com/code/chocozzz/house-price-prediction-eda-updated-2019-03-12#Ensemble

# %% [markdown]
# ## (6) Model Tuning : Cross Validation & Hyper-Parameter Tuning

# %% [markdown]
# ### 6.1. Cross Validation

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
xgb = XGBRegressor(random_state=2022)
lgb = LGBMRegressor(random_state=2022)
rfr = RandomForestRegressor(random_state=2022)
ridge = RidgeCV(cv=10)
olr = LinearRegression()

# linear regression
# decision tree
# model extra

models  = [xgb,lgb,rfr,ridge,olr]

# %%
for model in models:
    result = cross_val_score(model, X_t, y_t, cv=5, n_jobs = 5)
    print(f'{model.__class__.__name__} : {result}')
# Out:
# XGBRegressor : [0.90292291 0.90035877 0.89425156 0.90374999 0.89068146]
# LGBMRegressor : [0.9117328  0.90096411 0.90071789 0.9103111  0.89660289]
# RandomForestRegressor : [0.89775716 0.88198798 0.88735781 0.89641709 0.88288083]
# RidgeCV : [0.86663547 0.85505538 0.85038643 0.86083145 0.85435931]
# LinearRegression : [0.86698375 0.85725441 0.85119918 0.86098705 0.85525172]

# %% [markdown]
# ### 6.2. Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
from tqdm import tqdm
import time

def myGrid(model, param,x, y):
    start = time.time()
    mygrid = GridSearchCV(model, param_grid = param, scoring = 'neg_mean_squared_error', n_jobs=5, verbose=1)
    mygrid.fit(x,y)
    params= mygrid.cv_results_['params']
    score= mygrid.cv_results_['mean_test_score']
    for i in tqdm(range(len(params))):
        params[i]['score'] = score[i]
    
    print(f'(time lapsed : {time.time() - start} sec.)')
    return pd.DataFrame(params).sort_values(by='score', ascending=False)

# %% [markdown]
# ### 6.2.1. LGBMregressor

# %%
param_grid = {'max_depth' : [-1,15,32], 'n_estimators' : [100,1100,3100], 
              'num_leaves':[43,50,112],'learning_rate': [0.1, 0.015]}

# %%
result = myGrid(lgb,param_grid,X_t,y_t)
result
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#     learning_rate  max_depth  n_estimators  num_leaves     score
# 39          0.015         15          1100          43 -0.025543
# 40          0.015         15          1100          50 -0.025567
# 31          0.015         -1          1100          50 -0.025587
# 49          0.015         32          1100          50 -0.025587
# 30          0.015         -1          1100          43 -0.025605
# 48          0.015         32          1100          43 -0.025605
# 51          0.015         32          3100          43 -0.025611
# 33          0.015         -1          3100          43 -0.025611
# 42          0.015         15          3100          43 -0.025622
# 43          0.015         15          3100          50 -0.025740
# 34          0.015         -1          3100          50 -0.025755
# 52          0.015         32          3100          50 -0.025755
# 41          0.015         15          1100         112 -0.026215
# 10          0.100         15           100          50 -0.026270
# 50          0.015         32          1100         112 -0.026289
# 32          0.015         -1          1100         112 -0.026298
# 1           0.100         -1           100          50 -0.026323
# 19          0.100         32           100          50 -0.026323
# 9           0.100         15           100          43 -0.026348
# 18          0.100         32           100          43 -0.026355
# 0           0.100         -1           100          43 -0.026355
# 44          0.015         15          3100         112 -0.026619
# 53          0.015         32          3100         112 -0.026735
# 35          0.015         -1          3100         112 -0.026760
# 3           0.100         -1          1100          43 -0.026812
# 21          0.100         32          1100          43 -0.026812
# 12          0.100         15          1100          43 -0.026839
# 13          0.100         15          1100          50 -0.026870
# 22          0.100         32          1100          50 -0.026878
# 4           0.100         -1          1100          50 -0.026878
# 2           0.100         -1           100         112 -0.026898
# 20          0.100         32           100         112 -0.026945
# 11          0.100         15           100         112 -0.026958
# 24          0.100         32          3100          43 -0.027088
# 6           0.100         -1          3100          43 -0.027088
# 25          0.100         32          3100          50 -0.027110
# 7           0.100         -1          3100          50 -0.027110
# 16          0.100         15          3100          50 -0.027116
# 15          0.100         15          3100          43 -0.027124
# 5           0.100         -1          1100         112 -0.027657
# 14          0.100         15          1100         112 -0.027674
# 8           0.100         -1          3100         112 -0.027679
# 23          0.100         32          1100         112 -0.027684
# 26          0.100         32          3100         112 -0.027707
# 17          0.100         15          3100         112 -0.027718
# 47          0.015         32           100         112 -0.047262
# 29          0.015         -1           100         112 -0.047262
# 38          0.015         15           100         112 -0.047265
# 46          0.015         32           100          50 -0.050888
# 37          0.015         15           100          50 -0.050888
# 28          0.015         -1           100          50 -0.050888
# 45          0.015         32           100          43 -0.051982
# 36          0.015         15           100          43 -0.051982
# 27          0.015         -1           100          43 -0.051982

# %%
param_grid = {'max_depth' : 15, 'n_estimators' : 1100, 
              'num_leaves': 43,'learning_rate': 0.015}
lgb = LGBMRegressor(random_state=2022, objective= 'regression', **param_grid)
p1 = get_score_prediction(lgb, X_t, y_t,X_v, y_v)
# Out:
# RMSE is : 105711.66376807308

# %% [markdown]
# ### 6.2.2. XGBRegressor

# %%
param_grid ={'colsample_bytree' : 0.4603, 'gamma' : 0.0468, 'learning_rate' : 0.015,
             'max_depth' : 15, 'min_child_weight' : 32, 'n_estimators' : 1100,
             'reg_alpha' : 0.4640,'reg_lambda' : 0.8571,'subsample' : 0.8}
xgb = XGBRegressor(random_state=2022, **param_grid)
p2 = get_score_prediction(xgb, X_t, y_t, X_v, y_v)
# Out:
# RMSE is : 106693.17487314192

# %% [markdown]
# ### 6.2.3. RandomForestRegressor

# %%
param_grid = {'n_estimators' : [200,300,1100] ,  'max_depth' : [2,15,32,30]}
rfr = RandomForestRegressor(random_state=2022)
result = myGrid(rfr,param_grid,X_t,y_t)
result
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# 100%|████████████████████████████████████████| 12/12 [00:00<00:00, 91678.78it/s]
# (time lapsed : 1205.9255058765411 sec.)
#     max_depth  n_estimators     score
# 11         30          1100 -0.030486
# 8          32          1100 -0.030490
# 10         30           300 -0.030565
# 7          32           300 -0.030580
# 9          30           200 -0.030671
# 6          32           200 -0.030681
# 5          15          1100 -0.030761
# 4          15           300 -0.030840
# 3          15           200 -0.030922
# 1           2           300 -0.111166
# 0           2           200 -0.111318
# 2           2          1100 -0.111330

# %%
param_grid = {'n_estimators' : 1100, 'max_depth' : 30}
rfr = LGBMRegressor(random_state= 2022, **param_grid)
p3 = get_score_prediction(rfr, X_t, y_t,X_v, y_v)
# Out:
# RMSE is : 105700.8554116284

# %% [markdown]
# ### 6.2.4. Ridge Regressor

# %%
param_grid = {'cv' : [3,10,30,50,74,100]}
ridge = RidgeCV()
result = myGrid(ridge,param_grid,X_t,y_t)
result
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 27776.85it/s]
# (time lapsed : 14.64053225517273 sec.)
#     cv     score
# 0    3 -0.039356
# 1   10 -0.039356
# 2   30 -0.039356
# 3   50 -0.039356
# 4   74 -0.039356
# 5  100 -0.039356

# %%
param_grid = {'cv' : 3, 'alphas':(0.1, 1.0, 10.0, 6.4)}
ridge = RidgeCV( **param_grid)
p4 = get_score_prediction(ridge, X_t, y_t,X_v, y_v)
# Out:
# RMSE is : 141266.6342165597

# %% [markdown]
# ### 6.2.5. LinearRegression

# %%
olr = LinearRegression()
p5 = get_score_prediction(olr,X_t, y_t,X_v, y_v)
# Out:
# RMSE is : 141212.3557614117

# %% [markdown]
# ### 6.3. Blending

# %%
def AveragingBlending(models, x, y, sub_x) :
    predictions = np.column_stack([
        m.predict(sub_x) for m in models])
    return np.mean(predictions, axis=1)

# %%
models  = [xgb,lgb,rfr] #ridge,olr
y_pred = AveragingBlending(models, X_t, y_t, X_v)
mean_squared_error(np.expm1(y_v),np.expm1(y_pred)) **0.5
# Out:
# 103918.85613721068

# %% [markdown]
# ### 6.4. Ensemble

# %%
ensemble_pred = (p1 *0.35)+ (p2 * 0.35) + (p3 * 0.3)# + (p4 * 0.1) + (p5 * 0.1)
mean_squared_error(np.expm1(y_v), ensemble_pred) **0.5
# Out:
# 103879.643442809

# %% [markdown]
# ### 6.5. Feature Importance

# %%
pd.DataFrame(data = lgb.feature_importances_, columns = ['features'], index = selected_feature ).sort_values(by='features', ascending=False)
# Out:
#                   features
# long                  3785
# bellevue_dist         2992
# sqft_lot              2908
# date                  2875
# sqft_total_size       2808
# seattle_dist          2790
# yr_renovated          2775
# centroid_dist         2751
# sqft_living15         2705
# sqft_above            2331
# sqft_lot15            2276
# floor_area_ratio      2079
# lat                   1758
# yr_built              1681
# zipcode               1679
# grade_condition       1233
# rooms                 1011
# grade                  990
# sqft_basement          984
# bathrooms              834
# view                   777
# condition              421
# floors                 384
# bedrooms               317
# waterfront             305
# region_6               125
# region_2               102
# region_10               87
# region_12               85
# region_7                63
# region_3                56
# region_8                55
# region_4                45
# region_16               40
# region_0                32
# region_15               32
# region_5                29

# %%
pd.DataFrame(data = xgb.feature_importances_, columns = ['features'], index = selected_feature ).sort_values(by='features', ascending=False)
# Out:
#                   features
# grade             0.339327
# sqft_total_size   0.133972
# view              0.099373
# waterfront        0.071130
# seattle_dist      0.068550
# lat               0.045085
# grade_condition   0.039727
# sqft_living15     0.032959
# bellevue_dist     0.020758
# sqft_above        0.017582
# bathrooms         0.014708
# centroid_dist     0.014052
# rooms             0.007569
# region_6          0.006022
# long              0.005708
# region_10         0.005375
# region_15         0.005258
# region_0          0.005166
# sqft_lot          0.004979
# yr_built          0.004963
# region_4          0.004835
# floor_area_ratio  0.004319
# zipcode           0.004303
# region_7          0.004165
# date              0.003921
# condition         0.003902
# region_12         0.003846
# yr_renovated      0.003587
# sqft_lot15        0.003541
# region_5          0.003432
# region_8          0.003193
# floors            0.002991
# region_16         0.002852
# bedrooms          0.002628
# sqft_basement     0.002549
# region_3          0.002195
# region_2          0.001478

# %%
pd.DataFrame(data = rfr.feature_importances_, columns = ['features'], index = selected_feature ).sort_values(by='features', ascending=False)
# Out:
#                   features
# date                  2776
# sqft_living15         2499
# long                  2202
# sqft_above            2070
# sqft_lot15            2070
# sqft_total_size       2053
# bellevue_dist         2047
# floor_area_ratio      1979
# sqft_lot              1910
# centroid_dist         1837
# seattle_dist          1650
# yr_renovated          1636
# yr_built              1213
# zipcode               1037
# lat                    995
# rooms                  983
# sqft_basement          893
# grade_condition        841
# bathrooms              626
# grade                  448
# condition              228
# floors                 220
# view                   211
# bedrooms               182
# waterfront              51
# region_7                43
# region_3                39
# region_16               37
# region_10               35
# region_12               33
# region_6                32
# region_4                28
# region_8                28
# region_2                23
# region_0                16
# region_5                15
# region_15               14

# %% [markdown]
# ### 6.6. train with all dataset

# %%
models  = [xgb,lgb,rfr,ridge,olr]
for model in models :
    model.fit(X_train, y_train)

# %% [markdown]
# ## (7) Submission

# %%
sub_id = test.id
sub_id.shape
# Out:
# (6468,)

# %%
def make_submission(model,test) :
    prediction = np.expm1(model.predict(test))
    sub = pd.DataFrame({'id':sub_id, 'price':prediction})
    sub.to_csv(f'../data/submission/submission_{model.__class__.__name__}.csv', index=False)

# %%
#lgb
make_submission(lgb, X_test)

# %%
#xgb
make_submission(xgb, X_test)

# %%
#rfr
make_submission(rfr, X_test)

# %%
sub = pd.DataFrame({'id':sub_id, 'price':np.expm1(rfr.predict(X_test))})
sub.to_csv(f'../data/submission/submission_RANDOMFOREST.csv', index=False)

# %%
#averaging blending
models  = [xgb,lgb,rfr] #ridge,olr
av_predictions = np.column_stack([
    m.predict(X_test) for m in models])

sub_av_pred = np.mean(av_predictions, axis=1)
sub = pd.DataFrame({'id':sub_id, 'price':np.expm1(sub_av_pred)})
sub.to_csv(f'../data/submission/submission_Averaging_Blending.csv', index=False)

# %%
#ensemble
m1 = np.expm1(lgb.predict(X_test))
m2 = np.expm1(xgb.predict(X_test))
m3 = np.expm1(rfr.predict(X_test))

emsemble_final_pred = (m1 *0.35)+ (m2 * 0.35) + (m3 * 0.1) +(m2 * 0.1) + (m3 * 0.1)
sub = pd.DataFrame({'id':sub_id, 'price':emsemble_final_pred})
sub.to_csv(f'../data/submission/submission_ensemble.csv', index=False)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
