# %% [markdown]
# # 프로젝트 : 모든 장르 간 편향성 측정해 보기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 지금까지 우리는 영화 시놉시스 코퍼스를 가지고 영화 구분과 영화 장르 간에 내재된 편향성을 측정하는 작업을 진행해 보았습니다. 어느 정도는 우리의 상식과 일치하는 편향성이 측정되었을 것입니다.
#
# 이번에는 모든 장르에 대해 영화 구분과의 편향성 정도를 측정해 보겠습니다. 대부분의 과정은 이전 스텝에서 이미 진행한 내용을 참고해서 동일하게 진행 가능할 것입니다.

# %%
import konlpy
import gensim
import sklearn
import seaborn
import time 

print(konlpy.__version__)
print(gensim.__version__)
print(sklearn.__version__)
print(seaborn.__version__)
# Out:
# 0.5.2
# 4.1.2
# 1.0
# 0.11.2

# %% [markdown]
# ## STEP 1. 형태소 분석기를 이용하여 품사가 명사인 경우 해당 단어를 추출하기

# %%
import os

with open(os.getenv('HOME')+'/aiffel/weat/synopsis.txt', 'r') as file:
    for i in range(10):
        print(file.readline(), end='')
# Out:
# 사운드 엔지니어 상우(유지태 분)는 치매에 걸린 할머니(백성희 분)와
#  젊은 시절 상처한 한 아버지(박인환 분), 고모(신신애 분)와 함께 살고 있다.
#  어느 겨울 그는 지방 방송국 라디오 PD 은수(이영애 분)를 만난다.
#  자연의 소리를 채집해 틀어주는 라디오 프로그램을 준비하는 은수는 상우와 녹음 여행을 떠난다.
#  자연스레 가까워지는 두 사람은 어느 날, 은수의 아파트에서 밤을 보낸다.
#  너무 쉽게 사랑에 빠진 두 사람... 상우는 주체할 수 없을 정도로 그녀에게 빨려든다.
#  그러나 겨울에 만난 두 사람의 관계는 봄을 지나 여름을 맞이하면서 삐걱거린다.
#  이혼 경험이 있는 은수는 상우에게 결혼할 생각이 없다며 부담스러운 표정을 내비친다.
#  "어떻게 사랑이 변하니?..."라고 묻는 상우에게 은수는 그저 "헤어져" 라고 단호하게 말한다.
#  영원히 변할 것 같지 않던 사랑이 변하고, 그 사실을 받아들이지 못하는 상우는 어찌 할 바를 모른다.

# %%
def read_token(file_name):
    okt = Okt()
    result = []
    with open(os.getenv('HOME')+'/aiffel/weat/'+file_name, 'r') as fread: 
        print(file_name, '파일을 읽고 있습니다.')
        while True:
            line = fread.readline() 
            if not line: break 
            tokenlist = okt.pos(line, stem=True, norm=True) 
            for word in tokenlist:
                if word[1] in ["Noun"]:#, "Adjective", "Verb"]:
                    result.append((word[0])) 
    return ' '.join(result)

# %%
# 약 15분정도 걸립니다.
from konlpy.tag import Okt
okt = Okt()
tokenized = []
with open(os.getenv('HOME')+'/aiffel/weat/synopsis.txt', 'r') as file:
    while True:
        line = file.readline()
        if not line: break
        words = okt.pos(line, stem=True, norm=True)
        res = []
        for w in words:
            if w[1] in ["Noun"]:      # "Adjective", "Verb" 등을 포함할 수도 있습니다.
                res.append(w[0])    # 명사일 때만 tokenized 에 저장하게 됩니다. 
        tokenized.append(res)

print("슝~")
# Out:
# 슝~

# %% [markdown]
# ## STEP 2. 추출된 결과로 embedding model 만들기

# %%
from gensim.models import Word2Vec

# tokenized에 담긴 데이터를 가지고 나만의 Word2Vec을 생성합니다. (Gensim 4.0 기준)
model = Word2Vec(tokenized, vector_size=100, window=5, min_count=3, sg=0)  
model.wv.most_similar(positive=['영화'])
# Out:
# [('작품', 0.8945498466491699),
#  ('다큐멘터리', 0.8527830243110657),
#  ('드라마', 0.8202164769172668),
#  ('영화로', 0.8039472103118896),
#  ('형식', 0.7882810235023499),
#  ('주제', 0.7787964940071106),
#  ('코미디', 0.77744460105896),
#  ('감동', 0.7709659337997437),
#  ('실화', 0.7674607634544373),
#  ('스토리', 0.7664850354194641)]

# %% [markdown]
# ## STEP 3. target, attribute 단어 셋 만들기

# %% [markdown]
# ## Target

# %%
import os
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from konlpy.tag import Okt

art_txt = 'synopsis_art.txt'
gen_txt = 'synopsis_gen.txt'

# %%
# 2개의 파일을 처리하는데 10분 가량 걸립니다. 
art = read_token(art_txt)
gen = read_token(gen_txt)
# Out:
# synopsis_art.txt 파일을 읽고 있습니다.
# synopsis_gen.txt 파일을 읽고 있습니다.

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform([art, gen])

print(X.shape)
# Out:
# (2, 41082)

# %%
print(vectorizer.vocabulary_['영화'])
print(vectorizer.get_feature_names()[23976])
# Out:
# 23976
# 영화

# %%
m1 = X[0].tocoo()   # art를 TF-IDF로 표현한 sparse matrix를 가져옵니다. 
m2 = X[1].tocoo()   # gen을 TF-IDF로 표현한 sparse matrix를 가져옵니다. 

w1 = [[i, j] for i, j in zip(m1.col, m1.data)]
w2 = [[i, j] for i, j in zip(m2.col, m2.data)]

w1.sort(key=lambda x: x[1], reverse=True)   #art를 구성하는 단어들을 TF-IDF가 높은 순으로 정렬합니다. 
w2.sort(key=lambda x: x[1], reverse=True)   #gen을 구성하는 단어들을 TF-IDF가 높은 순으로 정렬합니다. 

print('예술영화를 대표하는 단어들:')
for i in range(100):
    print(vectorizer.get_feature_names()[w1[i][0]], end=', ')

print('\n')
    
print('일반영화를 대표하는 단어들:')
for i in range(100):
    print(vectorizer.get_feature_names()[w2[i][0]], end=', ')
# Out:
# 예술영화를 대표하는 단어들:
# 그녀, 자신, 시작, 위해, 사랑, 사람, 영화, 친구, 남자, 가족, 이야기, 마을, 사건, 마음, 세상, 아버지, 아이, 엄마, 모든, 여자, 대한, 서로, 과연, 다시, 시간, 아들, 소녀, 아내, 다른, 사이, 영화제, 세계, 사실, 하나, 점점, 남편, 감독, 여행, 인생, 발견, 모두, 순간, 우리, 가장, 마지막, 생활, 아빠, 모습, 통해, 죽음, 기억, 비밀, 학교, 음악, 한편, 소년, 생각, 도시, 명의, 사고, 결혼, 전쟁, 때문, 위기, 이제, 최고, 이자, 과거, 일상, 경찰, 상황, 간다, 미국, 결심, 운명, 현실, 관계, 지금, 단편, 여인, 하루, 이름, 이후, 준비, 인간, 감정, 만난, 국제, 처음, 충격, 살인, 누구, 동안, 존재, 그린, 어머니, 연인, 계속, 동생, 작품,
#
# 일반영화를 대표하는 단어들:
# 자신, 그녀, 영화제, 위해, 사람, 시작, 국제, 영화, 친구, 사랑, 남자, 이야기, 대한, 서울, 여자, 사건, 남편, 아이, 가족, 아버지, 다른, 마을, 시간, 엄마, 아들, 모든, 단편, 마음, 사실, 다시, 세계, 모습, 작품, 통해, 생각, 서로, 세상, 발견, 감독, 아내, 관계, 소녀, 사이, 하나, 우리, 애니메이션, 때문, 여성, 죽음, 과연, 점점, 인간, 생활, 한편, 결혼, 상황, 모두, 기억, 명의, 소년, 여행, 가장, 간다, 순간, 이제, 도시, 비밀, 학교, 과거, 가지, 이자, 경찰, 마지막, 미국, 동안, 전쟁, 주인공, 대해, 존재, 현실, 연출, 사고, 살인, 일상, 어머니, 계속, 사회, 인생, 다큐멘터리, 부문, 섹스, 최고, 바로, 동생, 의도, 하루, 위기, 계획, 정체, 한국,

# %%
n = 15
w1_, w2_ = [], []
for i in range(100):
    w1_.append(vectorizer.get_feature_names()[w1[i][0]])
    w2_.append(vectorizer.get_feature_names()[w2[i][0]])

# w1에만 있고 w2에는 없는, 예술영화를 잘 대표하는 단어를 15개 추출한다.
target_art, target_gen = [], []
for i in range(100):
    if (w1_[i] not in w2_) and (w1_[i] in model.wv): target_art.append(w1_[i])
    if len(target_art) == n: break 

# w2에만 있고 w1에는 없는, 일반영화를 잘 대표하는 단어를 15개 추출한다.
for i in range(100):
    if (w2_[i] not in w1_) and (w2_[i] in model.wv): target_gen.append(w2_[i])
    if len(target_gen) == n: break

# %%
print(target_art)
# Out:
# ['아빠', '음악', '결심', '운명', '지금', '여인', '이름', '이후', '준비', '감정', '만난', '처음', '충격', '누구', '그린']

# %%
print(target_gen)
# Out:
# ['서울', '애니메이션', '여성', '가지', '주인공', '대해', '연출', '사회', '다큐멘터리', '부문', '섹스', '바로', '의도', '계획', '정체']

# %% [markdown]
# ## Attribute

# %%
genre_txt = ['synopsis_SF.txt', 'synopsis_family.txt', 'synopsis_show.txt', 'synopsis_horror.txt', 'synopsis_etc.txt', 
             'synopsis_documentary.txt', 'synopsis_drama.txt', 'synopsis_romance.txt', 'synopsis_musical.txt', 
             'synopsis_mystery.txt', 'synopsis_crime.txt', 'synopsis_historical.txt', 'synopsis_western.txt', 
             'synopsis_adult.txt', 'synopsis_thriller.txt', 'synopsis_animation.txt', 'synopsis_action.txt', 
             'synopsis_adventure.txt', 'synopsis_war.txt', 'synopsis_comedy.txt', 'synopsis_fantasy.txt']
genre_name = ['SF', '가족', '공연', '공포(호러)', '기타', '다큐멘터리', '드라마', '멜로로맨스', '뮤지컬', '미스터리', '범죄', '사극', '서부극(웨스턴)',
         '성인물(에로)', '스릴러', '애니메이션', '액션', '어드벤처', '전쟁', '코미디', '판타지']

# %%
genre = []

for file_name in genre_txt:
    start = time.time()
    genre.append(read_token(file_name))
    print(time.time() - start)
# Out:
# synopsis_SF.txt 파일을 읽고 있습니다.
# 11.791757583618164
# synopsis_family.txt 파일을 읽고 있습니다.
# 4.354836463928223
# synopsis_show.txt 파일을 읽고 있습니다.
# 4.537360668182373
# synopsis_horror.txt 파일을 읽고 있습니다.
# 32.25094485282898
# synopsis_etc.txt 파일을 읽고 있습니다.
# 28.423818111419678
# synopsis_documentary.txt 파일을 읽고 있습니다.
# 89.55622434616089
# synopsis_drama.txt 파일을 읽고 있습니다.
# 210.34364223480225
# synopsis_romance.txt 파일을 읽고 있습니다.
# 54.538227796554565
# synopsis_musical.txt 파일을 읽고 있습니다.
# 1.7848327159881592
# synopsis_mystery.txt 파일을 읽고 있습니다.
# 8.292301654815674
# synopsis_crime.txt 파일을 읽고 있습니다.
# 14.748188734054565
# synopsis_historical.txt 파일을 읽고 있습니다.
# 1.7763822078704834
# synopsis_western.txt 파일을 읽고 있습니다.
# 0.42392635345458984
# synopsis_adult.txt 파일을 읽고 있습니다.
# 25.843244552612305
# synopsis_thriller.txt 파일을 읽고 있습니다.
# 22.430671215057373
# synopsis_animation.txt 파일을 읽고 있습니다.
# 69.10522127151489
# synopsis_action.txt 파일을 읽고 있습니다.
# 58.6449511051178
# synopsis_adventure.txt 파일을 읽고 있습니다.
# 5.3604583740234375
# synopsis_war.txt 파일을 읽고 있습니다.
# 4.455214977264404
# synopsis_comedy.txt 파일을 읽고 있습니다.
# 57.05127024650574
# synopsis_fantasy.txt 파일을 읽고 있습니다.
# 6.470205545425415

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(genre)

print(X.shape)
# Out:
# (21, 42191)

# %%
m = [X[i].tocoo() for i in range(X.shape[0])]

w = [[[i, j] for i, j in zip(mm.col, mm.data)] for mm in m]

for i in range(len(w)):
    w[i].sort(key=lambda x: x[1], reverse=True)
attributes = []
for i in range(len(w)):
    print(genre_name[i], end=': ')
    attr = []
    j = 0
    while (len(attr) < 15):
        if vectorizer.get_feature_names()[w[i][j][0]] in model.wv:
            attr.append(vectorizer.get_feature_names_out()[w[i][j][0]])
            print(vectorizer.get_feature_names()[w[i][j][0]], end=', ')
        j += 1
    attributes.append(attr)
    print()
# Out:
# SF: 위해, 자신, 지구, 시작, 사람, 인류, 인간, 미래, 우주, 그녀, 로봇, 세계, 모든, 박사, 우주선,
# 가족: 엄마, 아빠, 가족, 영화제, 자신, 위해, 친구, 아주르, 아버지, 시작, 그녀, 아들, 마을, 국제, 낙타,
# 공연: 오페라, 사랑, 토스카, 실황, 올레, 자신, 카바, 그녀, 공연, 오텔로, 리골레토, 백작, 프레, 베르디, 위해,
# 공포(호러): 시작, 위해, 사람, 자신, 친구, 그녀, 사건, 공포, 발견, 죽음, 마을, 가족, 악령, 남자, 좀비,
# 기타: 영화제, 국제, 서울, 단편, 영화, 자신, 사람, 이야기, 그녀, 남자, 위해, 시작, 사랑, 뉴미디어, 페스티벌,
# 다큐멘터리: 영화제, 영화, 다큐, 국제, 다큐멘터리, 사람, 이야기, 대한, 자신, 감독, 위해, 서울, 우리, 시작, 세계,
# 드라마: 자신, 영화제, 그녀, 사람, 사랑, 영화, 위해, 시작, 국제, 남자, 친구, 이야기, 엄마, 여자, 아버지,
# 멜로로맨스: 그녀, 사랑, 자신, 시작, 남편, 남자, 여자, 사람, 친구, 섹스, 위해, 마음, 결혼, 서로, 아내,
# 뮤지컬: 뮤지컬, 사랑, 에스메랄다, 그녀, 음악, 충무로, 모차르트, 영화, 토스카, 자신, 니웨, 카바, 영화제, 바흐, 페뷔스,
# 미스터리: 사건, 그녀, 시작, 자신, 위해, 사람, 발견, 사고, 진실, 죽음, 기억, 살인, 친구, 아내, 남자,
# 범죄: 사건, 위해, 자신, 경찰, 시작, 그녀, 범죄, 조직, 살인, 사람, 마약, 형사, 남자, 모든, 살해,
# 사극: 조선, 위해, 시작, 신기전, 사랑, 자신, 아가멤논, 황제, 그녀, 루안, 최고, 운명, 사람, 하선, 전쟁,
# 서부극(웨스턴): 서부, 보안관, 위해, 벌린, 카우보이, 그레이프바인, 헨리, 마을, 자신, 개릿, 아이, 시작, 무법자, 프린트, 마적,
# 성인물(에로): 그녀, 남편, 마사지, 자신, 섹스, 관계, 영화, 정사, 남자, 위해, 시작, 여자, 유부녀, 마음, 사랑,
# 스릴러: 자신, 그녀, 사건, 시작, 위해, 사람, 살인, 남자, 발견, 아내, 경찰, 친구, 모든, 사실, 살해,
# 애니메이션: 애니메이션, 국제, 영화제, 친구, 인디애니페스트, 위해, 자신, 시작, 사람, 페스티벌, 서울, 이야기, 아이, 마을, 소녀,
# 액션: 위해, 자신, 시작, 조직, 사건, 사람, 그녀, 경찰, 전쟁, 모든, 목숨, 사실, 친구, 가족, 요원,
# 어드벤처: 위해, 자신, 시작, 친구, 마을, 아버지, 영화, 아이, 사람, 여행, 세계, 앤트, 세상, 가족, 모험,
# 전쟁: 전쟁, 독일군, 전투, 위해, 작전, 시작, 부대, 윈터스, 독일, 연합군, 미군, 임무, 자신, 사람, 나치,
# 코미디: 그녀, 자신, 시작, 위해, 사랑, 사람, 친구, 영화, 남자, 여자, 영화제, 가족, 과연, 마을, 사건,
# 판타지: 자신, 그녀, 시작, 위해, 사람, 사랑, 요괴, 영화제, 이야기, 영화, 소녀, 남자, 인간, 세상, 마을,

# %% [markdown]
# ## STEP 4. WEAT score 계산과 시각화

# %%
def cos_sim(i, j):
    return dot(i, j.T)/(norm(i)*norm(j))

def s(w, A, B):
    c_a = cos_sim(w, A)
    c_b = cos_sim(w, B)
    mean_A = np.mean(c_a, axis=-1)
    mean_B = np.mean(c_b, axis=-1)
    return mean_A - mean_B #, c_a, c_b

def weat_score(X, Y, A, B):
    
    s_X = s(X, A, B)
    s_Y = s(Y, A, B)

    mean_X = np.mean(s_X)
    mean_Y = np.mean(s_Y)
    
    std_dev = np.std(np.concatenate([s_X, s_Y], axis=0))
    
    return (mean_X-mean_Y)/std_dev

# %%
matrix = [[0 for _ in range(len(genre_name))] for _ in range(len(genre_name))]
print("슝~")
# Out:
# 슝~

# %%
X = np.array([model.wv[word] for word in target_art])
Y = np.array([model.wv[word] for word in target_gen])

for i in range(len(genre_name)-1):
    for j in range(i+1, len(genre_name)):
        A = np.array([model.wv[word] for word in attributes[i]])
        B = np.array([model.wv[word] for word in attributes[j]])
        matrix[i][j] = weat_score(X, Y, A, B)

print("슝~")
# Out:
# 슝~

# %%
for i in range(len(genre_name)-1):
    for j in range(i+1, len(genre_name)):
        print(genre_name[i], genre_name[j],matrix[i][j])
# Out:
# SF 가족 -0.5252552
# SF 공연 -0.37260097
# SF 공포(호러) -0.6919751
# SF 기타 0.35588145
# SF 다큐멘터리 0.59292614
# SF 드라마 -0.3609866
# SF 멜로로맨스 -0.79088235
# SF 뮤지컬 0.32601762
# SF 미스터리 -0.6900718
# SF 범죄 -0.21138507
# SF 사극 -0.84529835
# SF 서부극(웨스턴) -0.43064255
# SF 성인물(에로) -0.55277485
# SF 스릴러 -0.51211447
# SF 애니메이션 0.35591397
# SF 액션 -0.4534214
# SF 어드벤처 -0.7955165
# SF 전쟁 0.22972743
# SF 코미디 -0.46060383
# SF 판타지 -0.18744604
# 가족 공연 0.22229712
# 가족 공포(호러) -0.1584791
# 가족 기타 0.76197565
# 가족 다큐멘터리 0.8364669
# 가족 드라마 0.26105413
# 가족 멜로로맨스 -0.62017685
# 가족 뮤지컬 0.6972645
# 가족 미스터리 -0.29140398
# 가족 범죄 0.24658415
# 가족 사극 -0.07146944
# 가족 서부극(웨스턴) 0.46341893
# 가족 성인물(에로) -0.2834451
# 가족 스릴러 -0.10500671
# 가족 애니메이션 0.8660418
# 가족 액션 0.12430794
# 가족 어드벤처 -0.01968204
# 가족 전쟁 0.66959065
# 가족 코미디 0.21635446
# 가족 판타지 0.44021156
# 공연 공포(호러) -0.26330024
# 공연 기타 0.93008715
# 공연 다큐멘터리 0.92652744
# 공연 드라마 0.025413312
# 공연 멜로로맨스 -0.7148687
# 공연 뮤지컬 0.8768341
# 공연 미스터리 -0.35855287
# 공연 범죄 0.0940602
# 공연 사극 -0.40109995
# 공연 서부극(웨스턴) 0.03009493
# 공연 성인물(에로) -0.46824253
# 공연 스릴러 -0.20457625
# 공연 애니메이션 0.9072333
# 공연 액션 -0.035631347
# 공연 어드벤처 -0.23832996
# 공연 전쟁 0.58733267
# 공연 코미디 -0.027705614
# 공연 판타지 0.33079782
# 공포(호러) 기타 0.6546143
# 공포(호러) 다큐멘터리 0.7560315
# 공포(호러) 드라마 0.32814488
# 공포(호러) 멜로로맨스 -0.6050824
# 공포(호러) 뮤지컬 0.61617655
# 공포(호러) 미스터리 -0.5295924
# 공포(호러) 범죄 0.7004743
# 공포(호러) 사극 0.11437065
# 공포(호러) 서부극(웨스턴) 0.41132233
# 공포(호러) 성인물(에로) -0.18059921
# 공포(호러) 스릴러 0.067193046
# 공포(호러) 애니메이션 0.6683242
# 공포(호러) 액션 0.54317623
# 공포(호러) 어드벤처 0.17057325
# 공포(호러) 전쟁 0.6669361
# 공포(호러) 코미디 0.43293837
# 공포(호러) 판타지 0.52700794
# 기타 다큐멘터리 0.559991
# 기타 드라마 -0.8954476
# 기타 멜로로맨스 -0.9021148
# 기타 뮤지컬 -0.1523567
# 기타 미스터리 -0.6667256
# 기타 범죄 -0.37538287
# 기타 사극 -0.8445624
# 기타 서부극(웨스턴) -0.63157153
# 기타 성인물(에로) -0.82352185
# 기타 스릴러 -0.55853987
# 기타 애니메이션 -0.12221855
# 기타 액션 -0.4826262
# 기타 어드벤처 -0.81521416
# 기타 전쟁 -0.23368101
# 기타 코미디 -0.7543444
# 기타 판타지 -0.71945703
# 다큐멘터리 드라마 -0.91939485
# 다큐멘터리 멜로로맨스 -0.904421
# 다큐멘터리 뮤지컬 -0.7421433
# 다큐멘터리 미스터리 -0.75495875
# 다큐멘터리 범죄 -0.4945827
# 다큐멘터리 사극 -0.92295647
# 다큐멘터리 서부극(웨스턴) -0.7366926
# 다큐멘터리 성인물(에로) -0.8347499
# 다큐멘터리 스릴러 -0.6480473
# 다큐멘터리 애니메이션 -0.5400097
# 다큐멘터리 액션 -0.60641176
# 다큐멘터리 어드벤처 -0.96133107
# 다큐멘터리 전쟁 -0.43852362
# 다큐멘터리 코미디 -0.8369166
# 다큐멘터리 판타지 -0.91166466
# 드라마 멜로로맨스 -0.8458296
# 드라마 뮤지컬 0.8149947
# 드라마 미스터리 -0.42313978
# 드라마 범죄 0.088128164
# 드라마 사극 -0.37437558
# 드라마 서부극(웨스턴) 0.011265353
# 드라마 성인물(에로) -0.5750893
# 드라마 스릴러 -0.23732924
# 드라마 애니메이션 0.87955636
# 드라마 액션 -0.04756317
# 드라마 어드벤처 -0.31820744
# 드라마 전쟁 0.4569155
# 드라마 코미디 -0.08633872
# 드라마 판타지 0.50487417
# 멜로로맨스 뮤지컬 0.8636339
# 멜로로맨스 미스터리 0.45176566
# 멜로로맨스 범죄 0.8381291
# 멜로로맨스 사극 0.63263464
# 멜로로맨스 서부극(웨스턴) 0.7318876
# 멜로로맨스 성인물(에로) 0.84631616
# 멜로로맨스 스릴러 0.6523449
# 멜로로맨스 애니메이션 0.8809362
# 멜로로맨스 액션 0.7262113
# 멜로로맨스 어드벤처 0.58283716
# 멜로로맨스 전쟁 0.80006963
# 멜로로맨스 코미디 0.8931687
# 멜로로맨스 판타지 0.83084965
# 뮤지컬 미스터리 -0.63535225
# 뮤지컬 범죄 -0.34210044
# 뮤지컬 사극 -0.8089783
# 뮤지컬 서부극(웨스턴) -0.5702794
# 뮤지컬 성인물(에로) -0.7837774
# 뮤지컬 스릴러 -0.52491844
# 뮤지컬 애니메이션 -0.006256555
# 뮤지컬 액션 -0.45118162
# 뮤지컬 어드벤처 -0.7806115
# 뮤지컬 전쟁 -0.19133015
# 뮤지컬 코미디 -0.69142944
# 뮤지컬 판타지 -0.6672198
# 미스터리 범죄 1.0427276
# 미스터리 사극 0.26780438
# 미스터리 서부극(웨스턴) 0.49093953
# 미스터리 성인물(에로) -0.020366166
# 미스터리 스릴러 0.7945906
# 미스터리 애니메이션 0.6702609
# 미스터리 액션 0.78262055
# 미스터리 어드벤처 0.29863542
# 미스터리 전쟁 0.6863008
# 미스터리 코미디 0.5218816
# 미스터리 판타지 0.56107354
# 범죄 사극 -0.33096865
# 범죄 서부극(웨스턴) -0.10982382
# 범죄 성인물(에로) -0.47437415
# 범죄 스릴러 -0.9784032
# 범죄 애니메이션 0.3666115
# 범죄 액션 -0.42842078
# 범죄 어드벤처 -0.25090954
# 범죄 전쟁 0.35429892
# 범죄 코미디 -0.14237429
# 범죄 판타지 0.073880814
# 사극 서부극(웨스턴) 0.40517128
# 사극 성인물(에로) -0.27968088
# 사극 스릴러 -0.06049129
# 사극 애니메이션 0.8444272
# 사극 액션 0.21060012
# 사극 어드벤처 0.08136484
# 사극 전쟁 0.8876099
# 사극 코미디 0.4401775
# 사극 판타지 0.66857
# 서부극(웨스턴) 성인물(에로) -0.41130564
# 서부극(웨스턴) 스릴러 -0.29970253
# 서부극(웨스턴) 애니메이션 0.69852173
# 서부극(웨스턴) 액션 -0.082373016
# 서부극(웨스턴) 어드벤처 -0.3700208
# 서부극(웨스턴) 전쟁 0.6860767
# 서부극(웨스턴) 코미디 -0.062888615
# 서부극(웨스턴) 판타지 0.24699073
# 성인물(에로) 스릴러 0.2011815
# 성인물(에로) 애니메이션 0.7625357
# 성인물(에로) 액션 0.35135737
# 성인물(에로) 어드벤처 0.26797944
# 성인물(에로) 전쟁 0.5984157
# 성인물(에로) 코미디 0.5493916
# 성인물(에로) 판타지 0.61593866
# 스릴러 애니메이션 0.5603971
# 스릴러 액션 0.48281577
# 스릴러 어드벤처 0.094083145
# 스릴러 전쟁 0.5742457
# 스릴러 코미디 0.2768502
# 스릴러 판타지 0.37506375
# 애니메이션 액션 -0.48914918
# 애니메이션 어드벤처 -0.8955629
# 애니메이션 전쟁 -0.22064072
# 애니메이션 코미디 -0.74928224
# 애니메이션 판타지 -0.6954977
# 액션 어드벤처 -0.141398
# 액션 전쟁 0.5570356
# 액션 코미디 0.029606707
# 액션 판타지 0.22365242
# 어드벤처 전쟁 0.7057893
# 어드벤처 코미디 0.31969452
# 어드벤처 판타지 0.7339928
# 전쟁 코미디 -0.5298499
# 전쟁 판타지 -0.28699857
# 코미디 판타지 0.5250709

# %%
import numpy as np; 
import seaborn as sns; 

np.random.seed(0)

# 한글 지원 폰트
sns.set(font='NanumGothic')

# 마이너스 부호 

plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize = (15,10))
ax = sns.heatmap(matrix, xticklabels=genre_name, yticklabels=genre_name, annot=True,  cmap='RdYlGn_r')
ax
# Out:
# <AxesSubplot:>
