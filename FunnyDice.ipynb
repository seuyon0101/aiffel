# %%
import random

class FunnyDice:
    '''
    FunnyDice is a class that generates 'n' sided dice with random values
    selected at creating instance
    '''
    def __init__(self, n, start, end):
        self.start = start
        self.end = end
        self.n = random.sample(range(self.start,self.end), n)
    
    def show(self):
        '''
        returns and prints list of values created
        
        '''
        for i in self.n:
            print(i, end = ' ')
        return self.n
        
    def rethrow(self) :
        '''
        restarts and prints created valuedice
        needs to select sides, start/end of range
        
        '''
        number = int(input('how many sides : '))
        start = int(input('number range starts : '))
        end = int(input('number range ends : '))
        
        self.__init__(number,start,end)
        print(self.n)
    
    def getmin(self):
        '''
        returns and prints min value of list
        '''
        print(min(self.n))
        return min(self.n) 

    def getmax(self):
        '''
        returns and prints max value of list
        '''

        print(max(self.n))
        return max(self.n)
    
    def getsum(self):
        '''
        returns and prints the sum of all values
        
        '''
        
        print('total sum : ', sum(self.n))
        return sum(self.n)

# def main():
#     print('Hello welcome to Funny Dice game')
#     print("Okay let's start by throwing the dice")
#     n = int(input('how many sides do you want for your dice'))
#     start = int(input('range starts from: '))
#     end = int(input('range ends at : ))
